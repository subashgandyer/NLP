# %% [markdown]
# **Download if necessary**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### **Step 1: Import the libraries**

# %%
import nltk  
import numpy as np  
import random  
import string

import bs4 as bs  
import urllib.request  
import re

# %% [markdown]
# ### Step 2: Grab articles from wikipedia

# %%
raw_html = None('https://en.wikipedia.org/wiki/Natural_language_processing')  
raw_html = None

article_html = None

article_paragraphs = None

article_text = ''

for para in article_paragraphs:  
    article_text += para.text

# %%
article_text
# Out:
# 'Natural language processing (NLP) is a subfield of linguistics, computer science, information engineering, and artificial intelligence concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data.\nChallenges in natural language processing frequently involve speech recognition, natural language understanding, and natural language generation.\nThe history of natural language processing (NLP) generally started in the 1950s, although work can be found from earlier periods.\nIn 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence.\nThe Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.[2]  However, real progress was much slower, and after the ALPAC report in 1966, which found that ten-year-long research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.  Little further research in machine translation was conducted until the late 1980s, when the first statistical machine translation systems were developed.\nSome notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapist, written by Joseph Weizenbaum between 1964 and 1966.  Using almost no information about human thought or emotion, ELIZA sometimes provided a startlingly human-like interaction. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".\nDuring the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data.  Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).  During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky.\nUp to the 1980s, most natural language processing systems were based on complex sets of hand-written rules.  Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing.  This was due to both the steady increase in computational power (see Moore\'s law) and the gradual lessening of the dominance of Chomskyan theories of linguistics (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.[3] Some of the earliest-used machine learning algorithms, such as decision trees, produced systems of hard if-then rules similar to existing hand-written rules.  However, part-of-speech tagging introduced the use of hidden Markov models to natural language processing, and increasingly, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to the features making up the input data. The cache language models upon which many speech recognition systems now rely are examples of such statistical models.  Such models are generally more robust when given unfamiliar input, especially input that contains errors (as is very common for real-world data), and produce more reliable results when integrated into a larger system comprising multiple subtasks.\nMany of the notable early successes occurred in the field of machine translation, due especially to work at IBM Research, where successively more complicated  ...

# %% [markdown]
# ### Step 4: N-Grams = 3

# %%
ngrams = {}
words = 3

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    None

ngrams
# Out:
# Natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) is
# ) is a
# is a subfield
# a subfield of
# subfield of linguistics
# of linguistics ,
# linguistics , computer
# , computer science
# computer science ,
# science , information
# , information engineering
# information engineering ,
# engineering , and
# , and artificial
# and artificial intelligence
# artificial intelligence concerned
# intelligence concerned with
# concerned with the
# with the interactions
# the interactions between
# interactions between computers
# between computers and
# computers and human
# and human (
# human ( natural
# ( natural )
# natural ) languages
# ) languages ,
# languages , in
# , in particular
# in particular how
# particular how to
# how to program
# to program computers
# program computers to
# computers to process
# to process and
# process and analyze
# and analyze large
# analyze large amounts
# large amounts of
# amounts of natural
# of natural language
# natural language data
# language data .
# data . Challenges
# . Challenges in
# Challenges in natural
# in natural language
# natural language processing
# language processing frequently
# processing frequently involve
# frequently involve speech
# involve speech recognition
# speech recognition ,
# recognition , natural
# , natural language
# natural language understanding
# language understanding ,
# understanding , and
# , and natural
# and natural language
# natural language generation
# language generation .
# generation . The
# . The history
# The history of
# history of natural
# of natural language
# natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) generally
# ) generally started
# generally started in
# started in the
# in the 1950s
# the 1950s ,
# 1950s , although
# , although work
# although work can
# work can be
# can be found
# be found from
# found from earlier
# from earlier periods
# earlier periods .
# periods . In
# . In 1950
# In 1950 ,
# 1950 , Alan
# , Alan Turing
# Alan Turing published
# Turing published an
# published an article
# an article titled
# article titled ``
# titled `` Computing
# `` Computing Machinery
# Computing Machinery and
# Machinery and Intelligence
# and Intelligence ''
# Intelligence '' which
# '' which proposed
# which proposed what
# proposed what is
# what is now
# is now called
# now called the
# called the Turing
# the Turing test
# Turing test as
# test as a
# as a criterion
# a criterion of
# criterion of intelligence
# of intelligence .
# intelligence . The
# . The Georgetown
# The Georgetown experiment
# Georgetown experiment in
# experiment in 1954
# in 1954 involved
# 1954 involved fully
# involved fully automatic
# fully automatic translation
# automatic translation of
# translation of more
# of more than
# more than sixty
# than sixty Russian
# sixty Russian sentences
# Russian sentences into
# sentences into English
# into English .
# English . The
# . The authors
# The authors claimed
# authors claimed that
# claimed that within
# that within three
# within three or
# three or five
# or five years
# five years ,
# years , machine
# , machine translation
# machine translation would
# translation would be
# would be a
# be a solved
# a solved problem
# solved problem .
# problem . [
# . [ 2
# [ 2 ]
# 2 ] However
# ] However ,
# However , real
# , real progress
# real progress was
# progress was much
# was much slower
# much slower ,
# slower , and
# , and after
# and after the
# after the ALPAC
# the ALPAC report
# ALPAC report in
# report in 1966
# in 1966 ,
# 1966 , which
# , which found
# which found that
# found that ten-year-long
# that ten-year-long research
# ten-year-long research had
# research had failed
# had failed to
# failed to fulfill
# to fulfill the
# fulfill the expectations
# the expectations ,
# expectations , funding
# , funding for
# funding for machine
# for machine translation
# machine translation was
# translation was dramatically
# was dramatically reduced
# dramatically reduced .
# reduced . Little
# . Little further
# Little further research
# further research in
# research in machine
# in machine translation
# machine translation was
# translation was conducted
# was conducted until
# conducted until the
# until the late
# the late 1980s
# late 1980s ,
# 1980s , when
# , when the
# when the first
# the first statistical
# first statistical machine
# statistical machine translation
# machine translation systems
# translation systems were
# systems were developed
# were developed .
# developed . Some
# . Some notably
# Some notably successful
# notably successful natural
# successful natural language
# natural language processing
# language processing systems
# processing systems developed
# systems developed in
# developed in the
# in the 1960s
# the 1960s were
# 1960s were SHRDLU
# were SHRDLU ,
# SHRDLU , a
# , a natural
# a natural language
# natural language system
# language system working
# system working in
# working in restricted
# in restricted ``
# restricted `` blocks
# `` blocks worlds
# blocks worlds ''
# worlds '' with
# '' with restricted
# with restricted vocabularies
# restricted vocabularies ,
# vocabularies , and
# , and ELIZA
# and ELIZA ,
# ELIZA , a
# , a simulation
# a simulation of
# simulation of a
# of a Rogerian
# a Rogerian psychotherapist
# Rogerian psychotherapist ,
# psychotherapist , written
# , written by
# written by Joseph
# by Joseph Weizenbaum
# Joseph Weizenbaum between
# Weizenbaum between 1964
# between 1964 and
# 1964 and 1966
# and 1966 .
# 1966 . Using
# . Using almost
# Using almost no
# almost no information
# no information about
# information about human
# about human thought
# human thought or
# thought or emotion
# or emotion ,
# emotion , ELIZA
# , ELIZA sometimes
# ELIZA sometimes provided
# sometimes provided a
# provided a startlingly
# a startlingly human-like
# startlingly human-like interaction
# human-like interaction .
# interaction . When
# . When the
# When the ``
# the `` patient
# `` patient ''
# patient '' exceeded
# '' exceeded the
# exceeded the very
# the very small
# very small knowledge
# small knowledge base
# knowledge base ,
# base , ELIZA
# , ELIZA might
# ELIZA might provide
# might provide a
# provide a generic
# a generic response
# generic response ,
# response , for
# , for example
# for example ,
# example , responding
# , responding to
# responding to ``
# to `` My
# `` My head
# My head hurts
# head hurts ''
# hurts '' with
# '' with ``
# with `` Why
# `` Why do
# Why do you
# do you say
# you say your
# say your head
# your head hurts
# head hurts ?
# hurts ? ''
# ? '' .
# '' . During
# . During the
# During the 1970s
# the 1970s ,
# 1970s , many
# , many programmers
# many programmers began
# programmers began to
# began to write
# to write ``
# write `` conceptual
# `` conceptual ontologies
# conceptual ontologies ''
# ontologies '' ,
# '' , which
# , which structured
# which structured real-world
# structured real-world information
# real-world information into
# information into computer-understandable
# into computer-understandable data
# computer-understandable data .
# data . Examples
# . Examples are
# Examples are MARGIE
# are MARGIE (
# MARGIE ( Schank
# ( Schank ,
# Schank , 1975
# , 1975 )
# 1975 ) ,
# ) , SAM
# , SAM (
# SAM ( Cullingford
# ( Cullingford ,
# Cullingford , 1978
# , 1978 )
# 1978 ) ,
# ) , PAM
# , PAM (
# PAM ( Wilensky
# ( Wilensky ,
# Wilensky , 1978
# , 1978 )
# 1978 ) ,
# ) , TaleSpin
# , TaleSpin (
# TaleSpin ( Meehan
# ( Meehan ,
# Meehan , 1976
# , 1976 )
# 1976 ) ,
# ) , QUALM
# , QUALM (
# QUALM ( Lehnert
# ( Lehnert ,
# Lehnert , 1977
# , 1977 )
# 1977 ) ,
# ) , Politics
# , Politics (
# Politics ( Carbonell
# ( Carbonell ,
# Carbonell , 1979
# , 1979 )
# 1979 ) ,
# ) , and
# , and Plot
# and Plot Units
# Plot Units (
# Units ( Lehnert
# ( Lehnert 1981
# Lehnert 1981 )
# 1981 ) .
# ) . During
# . During this
# During this time
# this time ,
# time , many
# , many chatterbots
# many chatterbots were
# chatterbots were written
# were written including
# written including PARRY
# including PARRY ,
# PARRY , Racter
# , Racter ,
# Racter , and
# , and Jabberwacky
# and Jabberwacky .
# Jabberwacky . Up
# . Up to
# Up to the
# to the 1980s
# the 1980s ,
# 1980s , most
# , most natural
# most natural language
# natural language processing
# language processing systems
# processing systems were
# systems were based
# were based on
# based on complex
# on complex sets
# complex sets of
# sets of hand-written
# of hand-written rules
# hand-written rules .
# rules . Starting
# . Starting in
# Starting in the
# in the late
# the late 1980s
# late 1980s ,
# 1980s , however
# , however ,
# however , there
# , there was
# there was a
# was a revolution
# a revolution in
# revolution in natural
# in natural language
# natural language processing
# language processing with
# processing with the
# with the introduction
# the introduction of
# introduction of machine
# of machine learning
# machine learning algorithms
# learning algorithms for
# algorithms for language
# for language processing
# language processing .
# processing . This
# . This was
# This was due
# was due to
# due to both
# to both the
# both the steady
# the steady increase
# steady increase in
# increase in computational
# in computational power
# computational power (
# power ( see
# ( see Moore
# see Moore 's
# Moore 's law
# 's law )
# law ) and
# ) and the
# and the gradual
# the gradual lessening
# gradual lessening of
# lessening of the
# of the dominance
# the dominance of
# dominance of Chomskyan
# of Chomskyan theories
# Chomskyan theories of
# theories of linguistics
# of linguistics (
# linguistics ( e.g
# ( e.g .
# e.g . transformational
# . transformational grammar
# transformational grammar )
# grammar ) ,
# ) , whose
# , whose theoretical
# whose theoretical underpinnings
# theoretical underpinnings discouraged
# underpinnings discouraged the
# discouraged the sort
# the sort of
# sort of corpus
# of corpus linguistics
# corpus linguistics that
# linguistics that underlies
# that underlies the
# underlies the machine-learning
# the machine-learning approach
# machine-learning approach to
# approach to language
# to language processing
# language processing .
# processing . [
# . [ 3
# [ 3 ]
# 3 ] Some
# ] Some of
# Some of the
# of the earliest-used
# the earliest-used machine
# earliest-used machine learning
# machine learning algorithms
# learning algorithms ,
# algorithms , such
# , such as
# such as decision
# as decision trees
# decision trees ,
# trees , produced
# , produced systems
# produced systems of
# systems of hard
# of hard if-then
# hard if-then rules
# if-then rules similar
# rules similar to
# similar to existing
# to existing hand-written
# existing hand-written rules
# hand-written rules .
# rules . However
# . However ,
# However , part-of-speech
# , part-of-speech tagging
# part-of-speech tagging introduced
# tagging introduced the
# introduced the use
# the use of
# use of hidden
# of hidden Markov
# hidden Markov models
# Markov models to
# models to natural
# to natural language
# natural language processing
# language processing ,
# processing , and
# , and increasingly
# and increasingly ,
# increasingly , research
# , research has
# research has focused
# has focused on
# focused on statistical
# on statistical models
# statistical models ,
# models , which
# , which make
# which make soft
# make soft ,
# soft , probabilistic
# , probabilistic decisions
# probabilistic decisions based
# decisions based on
# based on attaching
# on attaching real-valued
# attaching real-valued weights
# real-valued weights to
# weights to the
# to the features
# the features making
# features making up
# making up the
# up the input
# the input data
# input data .
# data . The
# . The cache
# The cache language
# cache language models
# language models upon
# models upon which
# upon which many
# which many speech
# many speech recognition
# speech recognition systems
# recognition systems now
# systems now rely
# now rely are
# rely are examples
# are examples of
# examples of such
# of such statistical
# such statistical models
# statistical models .
# models . Such
# . Such models
# Such models are
# models are generally
# are generally more
# generally more robust
# more robust when
# robust when given
# when given unfamiliar
# given unfamiliar input
# unfamiliar input ,
# input , especially
# , especially input
# especially input that
# input that contains
# that contains errors
# contains errors (
# errors ( as
# ( as is
# as is very
# is very common
# very common for
# common for real-world
# for real-world data
# real-world data )
# data ) ,
# ) , and
# , and produce
# and produce more
# produce more reliable
# more reliable results
# reliable results when
# results when integrated
# when integrated into
# integrated into a
# into a larger
# a larger system
# larger system comprising
# system comprising multiple
# comprising multiple subtasks
# multiple subtasks .
# subtasks . Many
# . Many of
# Many of the
# of the notable
# the notable early
# notable early successes
# early successes occurred
# successes occurred in
# occurred in the
# in the field
# the field of
# field of machine
# of machine translation
# machine translation ,
# translation , due
# , due especially
# due especially to
# especially to work
# to work at
# work at IBM
# at IBM Research
# IBM Research ,
# Research , where
# , where successively
# where successively more
# successively more complicated
# more complicated statistical
# complicated statistical models
# statistical models were
# models were developed
# were developed .
# developed . These
# . These systems
# These systems were
# systems were able
# were able to
# able to take
# to take advantage
# take advantage of
# advantage of existing
# of existing multilingual
# existing multilingual textual
# multilingual textual corpora
# textual corpora that
# corpora that had
# that had been
# had been produced
# been produced by
# produced by the
# by the Parliament
# the Parliament of
# Parliament of Canada
# of Canada and
# Canada and the
# and the European
# the European Union
# European Union as
# Union as a
# as a result
# a result of
# result of laws
# of laws calling
# laws calling for
# calling for the
# for the translation
# the translation of
# translation of all
# of all governmental
# all governmental proceedings
# governmental proceedings into
# proceedings into all
# into all official
# all official languages
# official languages of
# languages of the
# of the corresponding
# the corresponding systems
# corresponding systems of
# systems of government
# of government .
# government . However
# . However ,
# However , most
# , most other
# most other systems
# other systems depended
# systems depended on
# depended on corpora
# on corpora specifically
# corpora specifically developed
# specifically developed for
# developed for the
# for the tasks
# the tasks implemented
# tasks implemented by
# implemented by these
# by these systems
# these systems ,
# systems , which
# , which was
# which was (
# was ( and
# ( and often
# and often continues
# often continues to
# continues to be
# to be )
# be ) a
# ) a major
# a major limitation
# major limitation in
# limitation in the
# in the success
# the success of
# success of these
# of these systems
# these systems .
# systems . As
# . As a
# As a result
# a result ,
# result , a
# , a great
# a great deal
# great deal of
# deal of research
# of research has
# research has gone
# has gone into
# gone into methods
# into methods of
# methods of more
# of more effectively
# more effectively learning
# effectively learning from
# learning from limited
# from limited amounts
# limited amounts of
# amounts of data
# of data .
# data . Recent
# . Recent research
# Recent research has
# research has increasingly
# has increasingly focused
# increasingly focused on
# focused on unsupervised
# on unsupervised and
# unsupervised and semi-supervised
# and semi-supervised learning
# semi-supervised learning algorithms
# learning algorithms .
# algorithms . Such
# . Such algorithms
# Such algorithms are
# algorithms are able
# are able to
# able to learn
# to learn from
# learn from data
# from data that
# data that has
# that has not
# has not been
# not been hand-annotated
# been hand-annotated with
# hand-annotated with the
# with the desired
# the desired answers
# desired answers ,
# answers , or
# , or using
# or using a
# using a combination
# a combination of
# combination of annotated
# of annotated and
# annotated and non-annotated
# and non-annotated data
# non-annotated data .
# data . Generally
# . Generally ,
# Generally , this
# , this task
# this task is
# task is much
# is much more
# much more difficult
# more difficult than
# difficult than supervised
# than supervised learning
# supervised learning ,
# learning , and
# , and typically
# and typically produces
# typically produces less
# produces less accurate
# less accurate results
# accurate results for
# results for a
# for a given
# a given amount
# given amount of
# amount of input
# of input data
# input data .
# data . However
# . However ,
# However , there
# , there is
# there is an
# is an enormous
# an enormous amount
# enormous amount of
# amount of non-annotated
# of non-annotated data
# non-annotated data available
# data available (
# available ( including
# ( including ,
# including , among
# , among other
# among other things
# other things ,
# things , the
# , the entire
# the entire content
# entire content of
# content of the
# of the World
# the World Wide
# World Wide Web
# Wide Web )
# Web ) ,
# ) , which
# , which can
# which can often
# can often make
# often make up
# make up for
# up for the
# for the inferior
# the inferior results
# inferior results if
# results if the
# if the algorithm
# the algorithm used
# algorithm used has
# used has a
# has a low
# a low enough
# low enough time
# enough time complexity
# time complexity to
# complexity to be
# to be practical
# be practical .
# practical . In
# . In the
# In the 2010s
# the 2010s ,
# 2010s , representation
# , representation learning
# representation learning and
# learning and deep
# and deep neural
# deep neural network-style
# neural network-style machine
# network-style machine learning
# machine learning methods
# learning methods became
# methods became widespread
# became widespread in
# widespread in natural
# in natural language
# natural language processing
# language processing ,
# processing , due
# , due in
# due in part
# in part to
# part to a
# to a flurry
# a flurry of
# flurry of results
# of results showing
# results showing that
# showing that such
# that such techniques
# such techniques [
# techniques [ 4
# [ 4 ]
# 4 ] [
# ] [ 5
# [ 5 ]
# 5 ] can
# ] can achieve
# can achieve state-of-the-art
# achieve state-of-the-art results
# state-of-the-art results in
# results in many
# in many natural
# many natural language
# natural language tasks
# language tasks ,
# tasks , for
# , for example
# for example in
# example in language
# in language modeling
# language modeling ,
# modeling , [
# , [ 6
# [ 6 ]
# 6 ] parsing
# ] parsing ,
# parsing , [
# , [ 7
# [ 7 ]
# 7 ] [
# ] [ 8
# [ 8 ]
# 8 ] and
# ] and many
# and many others
# many others .
# others . Popular
# . Popular techniques
# Popular techniques include
# techniques include the
# include the use
# the use of
# use of word
# of word embeddings
# word embeddings to
# embeddings to capture
# to capture semantic
# capture semantic properties
# semantic properties of
# properties of words
# of words ,
# words , and
# , and an
# and an increase
# an increase in
# increase in end-to-end
# in end-to-end learning
# end-to-end learning of
# learning of a
# of a higher-level
# a higher-level task
# higher-level task (
# task ( e.g.
# ( e.g. ,
# e.g. , question
# , question answering
# question answering )
# answering ) instead
# ) instead of
# instead of relying
# of relying on
# relying on a
# on a pipeline
# a pipeline of
# pipeline of separate
# of separate intermediate
# separate intermediate tasks
# intermediate tasks (
# tasks ( e.g.
# ( e.g. ,
# e.g. , part-of-speech
# , part-of-speech tagging
# part-of-speech tagging and
# tagging and dependency
# and dependency parsing
# dependency parsing )
# parsing ) .
# ) . In
# . In some
# In some areas
# some areas ,
# areas , this
# , this shift
# this shift has
# shift has entailed
# has entailed substantial
# entailed substantial changes
# substantial changes in
# changes in how
# in how NLP
# how NLP systems
# NLP systems are
# systems are designed
# are designed ,
# designed , such
# , such that
# such that deep
# that deep neural
# deep neural network-based
# neural network-based approaches
# network-based approaches may
# approaches may be
# may be viewed
# be viewed as
# viewed as a
# as a new
# a new paradigm
# new paradigm distinct
# paradigm distinct from
# distinct from statistical
# from statistical natural
# statistical natural language
# natural language processing
# language processing .
# processing . For
# . For instance
# For instance ,
# instance , the
# , the term
# the term neural
# term neural machine
# neural machine translation
# machine translation (
# translation ( NMT
# ( NMT )
# NMT ) emphasizes
# ) emphasizes the
# emphasizes the fact
# the fact that
# fact that deep
# that deep learning-based
# deep learning-based approaches
# learning-based approaches to
# approaches to machine
# to machine translation
# machine translation directly
# translation directly learn
# directly learn sequence-to-sequence
# learn sequence-to-sequence transformations
# sequence-to-sequence transformations ,
# transformations , obviating
# , obviating the
# obviating the need
# the need for
# need for intermediate
# for intermediate steps
# intermediate steps such
# steps such as
# such as word
# as word alignment
# word alignment and
# alignment and language
# and language modeling
# language modeling that
# modeling that were
# that were used
# were used in
# used in statistical
# in statistical machine
# statistical machine translation
# machine translation (
# translation ( SMT
# ( SMT )
# SMT ) .
# ) . In
# . In the
# In the early
# the early days
# early days ,
# days , many
# , many language-processing
# many language-processing systems
# language-processing systems were
# systems were designed
# were designed by
# designed by hand-coding
# by hand-coding a
# hand-coding a set
# a set of
# set of rules
# of rules ,
# rules , [
# , [ 9
# [ 9 ]
# 9 ] [
# ] [ 10
# [ 10 ]
# 10 ] e.g
# ] e.g .
# e.g . by
# . by writing
# by writing grammars
# writing grammars or
# grammars or devising
# or devising heuristic
# devising heuristic rules
# heuristic rules for
# rules for stemming
# for stemming .
# stemming . However
# . However ,
# However , this
# , this is
# this is rarely
# is rarely robust
# rarely robust to
# robust to natural
# to natural language
# natural language variation
# language variation .
# variation . Since
# . Since the
# Since the so-called
# the so-called ``
# so-called `` statistical
# `` statistical revolution
# statistical revolution ''
# revolution '' [
# '' [ 11
# [ 11 ]
# 11 ] [
# ] [ 12
# [ 12 ]
# 12 ] in
# ] in the
# in the late
# the late 1980s
# late 1980s and
# 1980s and mid
# and mid 1990s
# mid 1990s ,
# 1990s , much
# , much natural
# much natural language
# natural language processing
# language processing research
# processing research has
# research has relied
# has relied heavily
# relied heavily on
# heavily on machine
# on machine learning
# machine learning .
# learning . The
# . The machine-learning
# The machine-learning paradigm
# machine-learning paradigm calls
# paradigm calls instead
# calls instead for
# instead for using
# for using statistical
# using statistical inference
# statistical inference to
# inference to automatically
# to automatically learn
# automatically learn such
# learn such rules
# such rules through
# rules through the
# through the analysis
# the analysis of
# analysis of large
# of large corpora
# large corpora of
# corpora of typical
# of typical real-world
# typical real-world examples
# real-world examples (
# examples ( a
# ( a corpus
# a corpus (
# corpus ( plural
# ( plural ,
# plural , ``
# , `` corpora
# `` corpora ''
# corpora '' )
# '' ) is
# ) is a
# is a set
# a set of
# set of documents
# of documents ,
# documents , possibly
# , possibly with
# possibly with human
# with human or
# human or computer
# or computer annotations
# computer annotations )
# annotations ) .
# ) . Many
# . Many different
# Many different classes
# different classes of
# classes of machine-learning
# of machine-learning algorithms
# machine-learning algorithms have
# algorithms have been
# have been applied
# been applied to
# applied to natural-language-processing
# to natural-language-processing tasks
# natural-language-processing tasks .
# tasks . These
# . These algorithms
# These algorithms take
# algorithms take as
# take as input
# as input a
# input a large
# a large set
# large set of
# set of ``
# of `` features
# `` features ''
# features '' that
# '' that are
# that are generated
# are generated from
# generated from the
# from the input
# the input data
# input data .
# data . Some
# . Some of
# Some of the
# of the earliest-used
# the earliest-used algorithms
# earliest-used algorithms ,
# algorithms , such
# , such as
# such as decision
# as decision trees
# decision trees ,
# trees , produced
# , produced systems
# produced systems of
# systems of hard
# of hard if-then
# hard if-then rules
# if-then rules similar
# rules similar to
# similar to the
# to the systems
# the systems of
# systems of hand-written
# of hand-written rules
# hand-written rules that
# rules that were
# that were then
# were then common
# then common .
# common . Increasingly
# . Increasingly ,
# Increasingly , however
# , however ,
# however , research
# , research has
# research has focused
# has focused on
# focused on statistical
# on statistical models
# statistical models ,
# models , which
# , which make
# which make soft
# make soft ,
# soft , probabilistic
# , probabilistic decisions
# probabilistic decisions based
# decisions based on
# based on attaching
# on attaching real-valued
# attaching real-valued weights
# real-valued weights to
# weights to each
# to each input
# each input feature
# input feature .
# feature . Such
# . Such models
# Such models have
# models have the
# have the advantage
# the advantage that
# advantage that they
# that they can
# they can express
# can express the
# express the relative
# the relative certainty
# relative certainty of
# certainty of many
# of many different
# many different possible
# different possible answers
# possible answers rather
# answers rather than
# rather than only
# than only one
# only one ,
# one , producing
# , producing more
# producing more reliable
# more reliable results
# reliable results when
# results when such
# when such a
# such a model
# a model is
# model is included
# is included as
# included as a
# as a component
# a component of
# component of a
# of a larger
# a larger system
# larger system .
# system . Systems
# . Systems based
# Systems based on
# based on machine-learning
# on machine-learning algorithms
# machine-learning algorithms have
# algorithms have many
# have many advantages
# many advantages over
# advantages over hand-produced
# over hand-produced rules
# hand-produced rules :
# rules : The
# : The following
# The following is
# following is a
# is a list
# a list of
# list of some
# of some of
# some of the
# of the most
# the most commonly
# most commonly researched
# commonly researched tasks
# researched tasks in
# tasks in natural
# in natural language
# natural language processing
# language processing .
# processing . Some
# . Some of
# Some of these
# of these tasks
# these tasks have
# tasks have direct
# have direct real-world
# direct real-world applications
# real-world applications ,
# applications , while
# , while others
# while others more
# others more commonly
# more commonly serve
# commonly serve as
# serve as subtasks
# as subtasks that
# subtasks that are
# that are used
# are used to
# used to aid
# to aid in
# aid in solving
# in solving larger
# solving larger tasks
# larger tasks .
# tasks . Though
# . Though natural
# Though natural language
# natural language processing
# language processing tasks
# processing tasks are
# tasks are closely
# are closely intertwined
# closely intertwined ,
# intertwined , they
# , they are
# they are frequently
# are frequently subdivided
# frequently subdivided into
# subdivided into categories
# into categories for
# categories for convenience
# for convenience .
# convenience . A
# . A coarse
# A coarse division
# coarse division is
# division is given
# is given below
# given below .
# below . The
# . The first
# The first published
# first published work
# published work by
# work by an
# by an artificial
# an artificial intelligence
# artificial intelligence was
# intelligence was published
# was published in
# published in 2018
# in 2018 ,
# 2018 , 1
# , 1 the
# 1 the Road
# the Road ,
# Road , marketed
# , marketed as
# marketed as a
# as a novel
# a novel ,
# novel , contains
# , contains sixty
# contains sixty million
# sixty million words
# {'Natural language processing': ['('],
#  'language processing (': ['NLP', 'NLP'],
#  'processing ( NLP': [')', ')'],
#  '( NLP )': ['is', 'generally'],
#  'NLP ) is': ['a'],
#  ') is a': ['subfield', 'set'],
#  'is a subfield': ['of'],
#  'a subfield of': ['linguistics'],
#  'subfield of linguistics': [','],
#  'of linguistics ,': ['computer'],
#  'linguistics , computer': ['science'],
#  ', computer science': [','],
#  'computer science ,': ['information'],
#  'science , information': ['engineering'],
#  ', information engineering': [','],
#  'information engineering ,': ['and'],
#  'engineering , and': ['artificial'],
#  ', and artificial': ['intelligence'],
#  'and artificial intelligence': ['concerned'],
#  'artificial intelligence concerned': ['with'],
#  'intelligence concerned with': ['the'],
#  'concerned with the': ['interactions'],
#  'with the interactions': ['between'],
#  'the interactions between': ['computers'],
#  'interactions between computers': ['and'],
#  'between computers and': ['human'],
#  'computers and human': ['('],
#  'and human (': ['natural'],
#  'human ( natural': [')'],
#  '( natural )': ['languages'],
#  'natural ) languages': [','],
#  ') languages ,': ['in'],
#  'languages , in': ['particular'],
#  ', in particular': ['how'],
#  'in particular how': ['to'],
#  'particular how to': ['program'],
#  'how to program': ['computers'],
#  'to program computers': ['to'],
#  'program computers to': ['process'],
#  'computers to process': ['and'],
#  'to process and': ['analyze'],
#  'process and analyze': ['large'],
#  'and analyze large': ['amounts'],
#  'analyze large amounts': ['of'],
#  'large amounts of': ['natural'],
#  'amounts of natural': ['language'],
#  'of natural language': ['data', 'processing'],
#  'natural language data': ['.'],
#  'language data .': ['Challenges'],
#  'data . Challenges': ['in'],
#  '. Challenges in': ['natural'],
#  'Challenges in natural': ['language'],
#  'in natural language': ['processing',
#   'processing',
#   'processing',
#   'processing'],
#  'natural language processing': ['frequently',
#   '(',
#   'systems',
#   'systems',
#   'with',
#   ',',
#   ',',
#   '.',
#   'research',
#   '.',
#   'tasks'],
#  'language processing frequently': ['involve'],
#  'processing frequently involve': ['speech'],
#  'frequently involve speech': ['recognition'],
#  'involve speech recognition': [','],
#  'speech recognition ,': ['natural'],
#  'recognition , natural': ['language'],
#  ', natural language': ['understanding'],
#  'natural language understanding': [','],
#  'language understanding ,': ['and'],
#  'understanding , and': ['natural'],
#  ', and natural': ['language'],
#  'and natural language': ['generation'],
#  'natural language generation': ['.'],
#  'language generation .': ['The'],
#  'generation . The': ['history'],
#  '. The history': ['of'],
#  'The history of': ['natural'],
#  'history of natural': ['language'],
#  'NLP ) generally': ['started'],
#  ') generally started': ['in'],
#  'generally started in': ['the'],
#  'started in the': ['1950s'],
#  'in the 1950s': [','],
#  'the 1950s ,': ['although'],
#  '1950s , although': ['work'],
#  ', although work': ['can'],
#  'although work can': ['be'],
#  'work can be': ['found'],
#  'can be found': ['from'],
#  'be found from': ['earlier'],
#  'found from earlier': ['periods'],
#  'from earlier periods': ['.'],
#  'earlier periods .': ['In'],
#  'periods . In': ['1950'],
#  '. In 1950': [','],
#  'In 1950 ,': ['Alan'],
#  '1950 , Alan': ['Turing'],
#  ', Alan Turing': ['published'],
#  'Alan Turing published': ['an'],
#  'Turing published an': ['article'],
#  'published an article': ['titled'],
#  'an article titled': ['``'],
#  'article titled ``': ['Computing'],
#  'titled `` Computing': ['Machinery'],
#  '`` Computing Machinery': ['and'],
#  'Computing Machinery and': ['Intelligence'],
#  'Machinery and Intelligence': ["''"],
#  "and Intelligence ''": ['which'],
#  "Intelligence '' which": ['proposed'],
#  "'' which proposed": ['what'],
#  'which proposed what': ['is'],
#  'proposed what is': ['now'],
#  'what is now': ['called'],
#  'is now called': ['the'],
#  'now called the': ['Turing'],
#  'called the Turing': ['test'],
#  'the Turing test': ['as'],
#  'Turing test as': ['a'],
#  'test as a': ['criterion'],
#  'as a criterion': ['of'],
#  'a criterion of': ['intelligence'],
#  'criterion of intelligence': ['.'],
#  'of intelligence .': ['The'],
#  'intelligence . The': ['Georgetown'],
#  '. The Georgetown': ['experiment'],
#  'The Georgetown experiment': ['in'],
#  'Georgetown experiment in': ['1954'],
#  'experiment in 1954': ['involved'],
#  'in 1954 involved': ['fully'],
#  '1954 involved fully': ['automatic'],
#  'involved fully automatic': ['translation'],
#  'fully automatic translation': ['of'],
#  'automatic translation of': ['more'],
#  'translation of more': ['than'],
#  'of more than': ['sixty'],
#  'more than sixty': ['Russian'],
#  'than sixty Russian': ['sentences'],
#  'sixty Russian sentences': ['into'],
#  'Russian sentences into': ['English'],
#  'sentences into English': ['.'],
#  'into English .': ['The'],
#  'English . The': ['authors'],
#  '. The authors': ['claimed'],
#  'The authors claimed': ['that'],
#  'authors claimed that': ['within'],
#  'claimed that within': ['three'],
#  'that within three': ['or'],
#  'within three or': ['five'],
#  'three or five': ['years'],
#  'or five years': [','],
#  'five years ,': ['machine'],
#  'years , machine': ['translation'],
#  ', machine translation': ['would'],
#  'machine translation would': ['be'],
#  'translation would be': ['a'],
#  'would be a': ['solved'],
#  'be a solved': ['problem'],
#  'a solved problem': ['.'],
#  'solved problem .': ['['],
#  'problem . [': ['2'],
#  '. [ 2': [']'],
#  '[ 2 ]': ['However'],
#  '2 ] However': [','],
#  '] However ,': ['real'],
#  'However , real': ['progress'],
#  ', real progress': ['was'],
#  'real progress was': ['much'],
#  'progress was much': ['slower'],
#  'was much slower': [','],
#  'much slower ,': ['and'],
#  'slower , and': ['after'],
#  ', and after': ['the'],
#  'and after the': ['ALPAC'],
#  'after the ALPAC': ['report'],
#  'the ALPAC report': ['in'],
#  'ALPAC report in': ['1966'],
#  'report in 1966': [','],
#  'in 1966 ,': ['which'],
#  '1966 , which': ['found'],
#  ', which found': ['that'],
#  'which found that': ['ten-year-long'],
#  'found that ten-year-long': ['research'],
#  'that ten-year-long research': ['had'],
#  'ten-year-long research had': ['failed'],
#  'research had failed': ['to'],
#  'had failed to': ['fulfill'],
#  'failed to fulfill': ['the'],
#  'to fulfill the': ['expectations'],
#  'fulfill the expectations': [','],
#  'the expectations ,': ['funding'],
#  'expectations , funding': ['for'],
#  ', funding for': ['machine'],
#  'funding for machine': ['translation'],
#  'for machine translation': ['was'],
#  'machine translation was': ['dramatically', 'conducted'],
#  'translation was dramatically': ['reduced'],
#  'was dramatically reduced': ['.'],
#  'dramatically reduced .': ['Little'],
#  'reduced . Little': ['further'],
#  '. Little further': ['research'],
#  'Little further research': ['in'],
#  'further research in': ['machine'],
#  'research in machine': ['translation'],
#  'in machine translation': ['was'],
#  'translation was conducted': ['until'],
#  'was conducted until': ['the'],
#  'conducted until the': ['late'],
#  'until the late': ['1980s'],
#  'the late 1980s': [',', ',', 'and'],
#  'late 1980s ,': ['when', 'however'],
#  '1980s , when': ['the'],
#  ', when the': ['first'],
#  'when the first': ['statistical'],
#  'the first statistical': ['machine'],
#  'first statistical machine': ['translation'],
#  'statistical machine translation': ['systems', '('],
#  'machine translation systems': ['were'],
#  'translation systems were': ['developed'],
#  'systems were developed': ['.'],
#  'were developed .': ['Some', 'These'],
#  'developed . Some': ['notably'],
#  '. Some notably': ['successful'],
#  'Some notably successful': ['natural'],
#  'notably successful natural': ['language'],
#  'successful natural language': ['processing'],
#  'language processing systems': ['developed', 'were'],
#  'processing systems developed': ['in'],
#  'systems developed in': ['the'],
#  'developed in the': ['1960s'],
#  'in the 1960s': ['were'],
#  'the 1960s were': ['SHRDLU'],
#  '1960s were SHRDLU': [','],
#  'were SHRDLU ,': ['a'],
#  'SHRDLU , a': ['natural'],
#  ', a natural': ['language'],
#  'a natural language': ['system'],
#  'natural language system': ['working'],
#  'language system working': ['in'],
#  'system working in': ['restricted'],
#  'working in restricted': ['``'],
#  'in restricted ``': ['blocks'],
#  'restricted `` blocks': ['worlds'],
#  '`` blocks worlds': ["''"],
#  "blocks worlds ''": ['with'],
#  "worlds '' with": ['restricted'],
#  "'' with restricted": ['vocabularies'],
#  'with restricted vocabularies': [','],
#  'restricted vocabularies ,': ['and'],
#  'vocabularies , and': ['ELIZA'],
#  ', and ELIZA': [','],
#  'and ELIZA ,': ['a'],
#  'ELIZA , a': ['simulation'],
#  ', a simulation': ['of'],
#  'a simulation of': ['a'],
#  'simulation of a': ['Rogerian'],
#  'of a Rogerian': ['psychotherapist'],
#  'a Rogerian psychotherapist': [','],
#  'Rogerian psychotherapist ,': ['written'],
#  'psychotherapist , written': ['by'],
#  ', written by': ['Joseph'],
#  'written by Joseph': ['Weizenbaum'],
#  'by Joseph Weizenbaum': ['between'],
#  'Joseph Weizenbaum between': ['1964'],
#  'Weizenbaum between 1964': ['and'],
#  'between 1964 and': ['1966'],
#  '1964 and 1966': ['.'],
#  'and 1966 .': ['Using'],
#  '1966 . Using': ['almost'],
#  '. Using almost': ['no'],
#  'Using almost no': ['information'],
#  'almost no information': ['about'],
#  'no information about': ['human'],
#  'information about human': ['thought'],
#  'about human thought': ['or'],
#  'human thought or': ['emotion'],
#  'thought or emotion': [','],
#  'or emotion ,': ['ELIZA'],
#  'emotion , ELIZA': ['sometimes'],
#  ', ELIZA sometimes': ['provided'],
#  'ELIZA sometimes provided': ['a'],
#  'sometimes provided a': ['startlingly'],
#  'provided a startlingly': ['human-like'],
#  'a startlingly human-like': ['interaction'],
#  'startlingly human-like interaction': ['.'],
#  'human-like interaction .': ['When'],
#  'interaction . When': ['the'],
#  '. When the': ['``'],
#  'When the ``': ['patient'],
#  'the `` patient': ["''"],
#  "`` patient ''": ['exceeded'],
#  "patient '' exceeded": ['the'],
#  "'' exceeded the": ['very'],
#  'exceeded the very': ['small'],
#  'the very small': ['knowledge'],
#  'very small knowledge': ['base'],
#  'small knowledge base': [','],
#  'knowledge base ,': ['ELIZA'],
#  'base , ELIZA': ['might'],
#  ', ELIZA might': ['provide'],
#  'ELIZA might provide': ['a'],
#  'might provide a': ['generic'],
#  'provide a generic': ['response'],
#  'a generic response': [','],
#  'generic response ,': ['for'],
#  'response , for': ['example'],
#  ', for example': [',', 'in'],
#  'for example ,': ['responding'],
#  'example , responding': ['to'],
#  ', responding to': ['``'],
#  'responding to ``': ['My'],
#  'to `` My': ['head'],
#  '`` My head': ['hurts'],
#  'My head hurts': ["''"],
#  "head hurts ''": ['with'],
#  "hurts '' with": ['``'],
#  "'' with ``": ['Why'],
#  'with `` Why': ['do'],
#  '`` Why do': ['you'],
#  'Why do you': ['say'],
#  'do you say': ['your'],
#  'you say your': ['head'],
#  'say your head': ['hurts'],
#  'your head hurts': ['?'],
#  'head hurts ?': ["''"],
#  "hurts ? ''": ['.'],
#  "? '' .": ['During'],
#  "'' . During": ['the'],
#  '. During the': ['1970s'],
#  'During the 1970s': [','],
#  'the 1970s ,': ['many'],
#  '1970s , many': ['programmers'],
#  ', many programmers': ['began'],
#  'many programmers began': ['to'],
#  'programmers began to': ['write'],
#  'began to write': ['``'],
#  'to write ``': ['conceptual'],
#  'write `` conceptual': ['ontologies'],
#  '`` conceptual ontologies': ["''"],
#  "conceptual ontologies ''": [','],
#  "ontologies '' ,": ['which'],
#  "'' , which": ['structured'],
#  ', which structured': ['real-world'],
#  'which structured real-world': ['information'],
#  'structured real-world information': ['into'],
#  'real-world information into': ['computer-understandable'],
#  'information into computer-understandable': ['data'],
#  'into computer-understandable data': ['.'],
#  'computer-understandable data .': ['Examples'],
#  'data . Examples': ['are'],
#  '. Examples are': ['MARGIE'],
#  'Examples are MARGIE': ['('],
#  'are MARGIE (': ['Schank'],
#  'MARGIE ( Schank': [','],
#  '( Schank ,': ['1975'],
#  'Schank , 1975': [')'],
#  ', 1975 )': [','],
#  '1975 ) ,': ['SAM'],
#  ') , SAM': ['('],
#  ', SAM (': ['Cullingford'],
#  'SAM ( Cullingford': [','],
#  '( Cullingford ,': ['1978'],
#  'Cullingford , 1978': [')'],
#  ', 1978 )': [',', ','],
#  '1978 ) ,': ['PAM', 'TaleSpin'],
#  ') , PAM': ['('],
#  ', PAM (': ['Wilensky'],
#  'PAM ( Wilensky': [','],
#  '( Wilensky ,': ['1978'],
#  'Wilensky , 1978': [')'],
#  ') , TaleSpin': ['('],
#  ', TaleSpin (': ['Meehan'],
#  'TaleSpin ( Meehan': [','],
#  '( Meehan ,': ['1976'],
#  'Meehan , 1976': [')'],
#  ', 1976 )': [','],
#  '1976 ) ,': ['QUALM'],
#  ') , QUALM': ['('],
#  ', QUALM (': ['Lehnert'],
#  'QUALM ( Lehnert': [','],
#  '( Lehnert ,': ['1977'],
#  'Lehnert , 1977': [')'],
#  ', 1977 )': [','],
#  '1977 ) ,': ['Politics'],
#  ') , Politics': ['('],
#  ', Politics (': ['Carbonell'],
#  'Politics ( Carbonell': [','],
#  '( Carbonell ,': ['1979'],
#  'Carbonell , 1979': [')'],
#  ', 1979 )': [','],
#  '1979 ) ,': ['and'],
#  ') , and': ['Plot', 'produce'],
#  ', and Plot': ['Units'],
#  'and Plot Units': ['('],
#  'Plot Units (': ['Lehnert'],
#  'Units ( Lehnert': ['1981'],
#  '( Lehnert 1981': [')'],
#  'Lehnert 1981 )': ['.'],
#  '1981 ) .': ['During'],
#  ') . During': ['this'],
#  '. During this': ['time'],
#  'During this time': [','],
#  'this time ,': ['many'],
#  'time , many': ['chatterbots'],
#  ', many chatterbots': ['were'],
#  'many chatterbots were': ['written'],
#  'chatterbots were written': ['including'],
#  'were written including': ['PARRY'],
#  'written including PARRY': [','],
#  'including PARRY ,': ['Racter'],
#  'PARRY , Racter': [','],
#  ', Racter ,': ['and'],
#  'Racter , and': ['Jabberwacky'],
#  ', and Jabberwacky': ['.'],
#  'and Jabberwacky .': ['Up'],
#  'Jabberwacky . Up': ['to'],
#  '. Up to': ['the'],
#  'Up to the': ['1980s'],
#  'to the 1980s': [','],
#  'the 1980s ,': ['most'],
#  '1980s , most': ['natural'],
#  ', most natural': ['language'],
#  'most natural language': ['processing'],
#  'processing systems were': ['based'],
#  'systems were based': ['on'],
#  'were based on': ['complex'],
#  'based on complex': ['sets'],
#  'on complex sets': ['of'],
#  'complex sets of': ['hand-written'],
#  'sets of hand-written': ['rules'],
#  'of hand-written rules': ['.', 'that'],
#  'hand-written rules .': ['Starting', 'However'],
#  'rules . Starting': ['in'],
#  '. Starting in': ['the'],
#  'Starting in the': ['late'],
#  'in the late': ['1980s', '1980s'],
#  '1980s , however': [','],
#  ', however ,': ['there', 'research'],
#  'however , there': ['was'],
#  ', there was': ['a'],
#  'there was a': ['revolution'],
#  'was a revolution': ['in'],
#  'a revolution in': ['natural'],
#  'revolution in natural': ['language'],
#  'language processing with': ['the'],
#  'processing with the': ['introduction'],
#  'with the introduction': ['of'],
#  'the introduction of': ['machine'],
#  'introduction of machine': ['learning'],
#  'of machine learning': ['algorithms'],
#  'machine learning algorithms': ['for', ','],
#  'learning algorithms for': ['language'],
#  'algorithms for language': ['processing'],
#  'for language processing': ['.'],
#  'language processing .': ['This', '[', 'For', 'Some'],
#  'processing . This': ['was'],
#  '. This was': ['due'],
#  'This was due': ['to'],
#  'was due to': ['both'],
#  'due to both': ['the'],
#  'to both the': ['steady'],
#  'both the steady': ['increase'],
#  'the steady increase': ['in'],
#  'steady increase in': ['computational'],
#  'increase in computational': ['power'],
#  'in computational power': ['('],
#  'computational power (': ['see'],
#  'power ( see': ['Moore'],
#  '( see Moore': ["'s"],
#  "see Moore 's": ['law'],
#  "Moore 's law": [')'],
#  "'s law )": ['and'],
#  'law ) and': ['the'],
#  ') and the': ['gradual'],
#  'and the gradual': ['lessening'],
#  'the gradual lessening': ['of'],
#  'gradual lessening of': ['the'],
#  'lessening of the': ['dominance'],
#  'of the dominance': ['of'],
#  'the dominance of': ['Chomskyan'],
#  'dominance of Chomskyan': ['theories'],
#  'of Chomskyan theories': ['of'],
#  'Chomskyan theories of': ['linguistics'],
#  'theories of linguistics': ['('],
#  'of linguistics (': ['e.g'],
#  'linguistics ( e.g': ['.'],
#  '( e.g .': ['transformational'],
#  'e.g . transformational': ['grammar'],
#  '. transformational grammar': [')'],
#  'transformational grammar )': [','],
#  'grammar ) ,': ['whose'],
#  ') , whose': ['theoretical'],
#  ', whose theoretical': ['underpinnings'],
#  'whose theoretical underpinnings': ['discouraged'],
#  'theoretical underpinnings discouraged': ['the'],
#  'underpinnings discouraged the': ['sort'],
#  'discouraged the sort': ['of'],
#  'the sort of': ['corpus'],
#  'sort of corpus': ['linguistics'],
#  'of corpus linguistics': ['that'],
#  'corpus linguistics that': ['underlies'],
#  'linguistics that underlies': ['the'],
#  'that underlies the': ['machine-learning'],
#  'underlies the machine-learning': ['approach'],
#  'the machine-learning approach': ['to'],
#  'machine-learning approach to': ['language'],
#  'approach to language': ['processing'],
#  'to language processing': ['.'],
#  'processing . [': ['3'],
#  '. [ 3': [']'],
#  '[ 3 ]': ['Some'],
#  '3 ] Some': ['of'],
#  '] Some of': ['the'],
#  'Some of the': ['earliest-used', 'earliest-used'],
#  'of the earliest-used': ['machine', 'algorithms'],
#  'the earliest-used machine': ['learning'],
#  'earliest-used machine learning': ['algorithms'],
#  'learning algorithms ,': ['such'],
#  'algorithms , such': ['as', 'as'],
#  ', such as': ['decision', 'decision'],
#  'such as decision': ['trees', 'trees'],
#  'as decision trees': [',', ','],
#  'decision trees ,': ['produced', 'produced'],
#  'trees , produced': ['systems', 'systems'],
#  ', produced systems': ['of', 'of'],
#  'produced systems of': ['hard', 'hard'],
#  'systems of hard': ['if-then', 'if-then'],
#  'of hard if-then': ['rules', 'rules'],
#  'hard if-then rules': ['similar', 'similar'],
#  'if-then rules similar': ['to', 'to'],
#  'rules similar to': ['existing', 'the'],
#  'similar to existing': ['hand-written'],
#  'to existing hand-written': ['rules'],
#  'existing hand-written rules': ['.'],
#  'rules . However': [','],
#  '. However ,': ['part-of-speech', 'most', 'there', 'this'],
#  'However , part-of-speech': ['tagging'],
#  ', part-of-speech tagging': ['introduced', 'and'],
#  'part-of-speech tagging introduced': ['the'],
#  'tagging introduced the': ['use'],
#  'introduced the use': ['of'],
#  'the use of': ['hidden', 'word'],
#  'use of hidden': ['Markov'],
#  'of hidden Markov': ['models'],
#  'hidden Markov models': ['to'],
#  'Markov models to': ['natural'],
#  'models to natural': ['language'],
#  'to natural language': ['processing', 'variation'],
#  'language processing ,': ['and', 'due'],
#  'processing , and': ['increasingly'],
#  ', and increasingly': [','],
#  'and increasingly ,': ['research'],
#  'increasingly , research': ['has'],
#  ', research has': ['focused', 'focused'],
#  'research has focused': ['on', 'on'],
#  'has focused on': ['statistical', 'statistical'],
#  'focused on statistical': ['models', 'models'],
#  'on statistical models': [',', ','],
#  'statistical models ,': ['which', 'which'],
#  'models , which': ['make', 'make'],
#  ', which make': ['soft', 'soft'],
#  'which make soft': [',', ','],
#  'make soft ,': ['probabilistic', 'probabilistic'],
#  'soft , probabilistic': ['decisions', 'decisions'],
#  ', probabilistic decisions': ['based', 'based'],
#  'probabilistic decisions based': ['on', 'on'],
#  'decisions based on': ['attaching', 'attaching'],
#  'based on attaching': ['real-valued', 'real-valued'],
#  'on attaching real-valued': ['weights', 'weights'],
#  'attaching real-valued weights': ['to', 'to'],
#  'real-valued weights to': ['the', 'each'],
#  'weights to the': ['features'],
#  'to the features': ['making'],
#  'the features making': ['up'],
#  'features making up': ['the'],
#  'making up the': ['input'],
#  'up the input': ['data'],
#  'the input data': ['.', '.'],
#  'input data .': ['The', 'However', 'Some'],
#  'data . The': ['cache'],
#  '. The cache': ['language'],
#  'The cache language': ['models'],
#  'cache language models': ['upon'],
#  'language models upon': ['which'],
#  'models upon which': ['many'],
#  'upon which many': ['speech'],
#  'which many speech': ['recognition'],
#  'many speech recognition': ['systems'],
#  'speech recognition systems': ['now'],
#  'recognition systems now': ['rely'],
#  'systems now rely': ['are'],
#  'now rely are': ['examples'],
#  'rely are examples': ['of'],
#  'are examples of': ['such'],
#  'examples of such': ['statistical'],
#  'of such statistical': ['models'],
#  'such statistical models': ['.'],
#  'statistical models .': ['Such'],
#  'models . Such': ['models'],
#  '. Such models': ['are', 'have'],
#  'Such models are': ['generally'],
#  'models are generally': ['more'],
#  'are generally more': ['robust'],
#  'generally more robust': ['when'],
#  'more robust when': ['given'],
#  'robust when given': ['unfamiliar'],
#  'when given unfamiliar': ['input'],
#  'given unfamiliar input': [','],
#  'unfamiliar input ,': ['especially'],
#  'input , especially': ['input'],
#  ', especially input': ['that'],
#  'especially input that': ['contains'],
#  'input that contains': ['errors'],
#  'that contains errors': ['('],
#  'contains errors (': ['as'],
#  'errors ( as': ['is'],
#  '( as is': ['very'],
#  'as is very': ['common'],
#  'is very common': ['for'],
#  'very common for': ['real-world'],
#  'common for real-world': ['data'],
#  'for real-world data': [')'],
#  'real-world data )': [','],
#  'data ) ,': ['and'],
#  ', and produce': ['more'],
#  'and produce more': ['reliable'],
#  'produce more reliable': ['results'],
#  'more reliable results': ['when', 'when'],
#  'reliable results when': ['integrated', 'such'],
#  'results when integrated': ['into'],
#  'when integrated into': ['a'],
#  'integrated into a': ['larger'],
#  'into a larger': ['system'],
#  'a larger system': ['comprising', '.'],
#  'larger system comprising': ['multiple'],
#  'system comprising multiple': ['subtasks'],
#  'comprising multiple subtasks': ['.'],
#  'multiple subtasks .': ['Many'],
#  'subtasks . Many': ['of'],
#  '. Many of': ['the'],
#  'Many of the': ['notable'],
#  'of the notable': ['early'],
#  'the notable early': ['successes'],
#  'notable early successes': ['occurred'],
#  'early successes occurred': ['in'],
#  'successes occurred in': ['the'],
#  'occurred in the': ['field'],
#  'in the field': ['of'],
#  'the field of': ['machine'],
#  'field of machine': ['translation'],
#  'of machine translation': [','],
#  'machine translation ,': ['due'],
#  'translation , due': ['especially'],
#  ', due especially': ['to'],
#  'due especially to': ['work'],
#  'especially to work': ['at'],
#  'to work at': ['IBM'],
#  'work at IBM': ['Research'],
#  'at IBM Research': [','],
#  'IBM Research ,': ['where'],
#  'Research , where': ['successively'],
#  ', where successively': ['more'],
#  'where successively more': ['complicated'],
#  'successively more complicated': ['statistical'],
#  'more complicated statistical': ['models'],
#  'complicated statistical models': ['were'],
#  'statistical models were': ['developed'],
#  'models were developed': ['.'],
#  'developed . These': ['systems'],
#  '. These systems': ['were'],
#  'These systems were': ['able'],
#  'systems were able': ['to'],
#  'were able to': ['take'],
#  'able to take': ['advantage'],
#  'to take advantage': ['of'],
#  'take advantage of': ['existing'],
#  'advantage of existing': ['multilingual'],
#  'of existing multilingual': ['textual'],
#  'existing multilingual textual': ['corpora'],
#  'multilingual textual corpora': ['that'],
#  'textual corpora that': ['had'],
#  'corpora that had': ['been'],
#  'that had been': ['produced'],
#  'had been produced': ['by'],
#  'been produced by': ['the'],
#  'produced by the': ['Parliament'],
#  'by the Parliament': ['of'],
#  'the Parliament of': ['Canada'],
#  'Parliament of Canada': ['and'],
#  'of Canada and': ['the'],
#  'Canada and the': ['European'],
#  'and the European': ['Union'],
#  'the European Union': ['as'],
#  'European Union as': ['a'],
#  'Union as a': ['result'],
#  'as a result': ['of'],
#  'a result of': ['laws'],
#  'result of laws': ['calling'],
#  'of laws calling': ['for'],
#  'laws calling for': ['the'],
#  'calling for the': ['translation'],
#  'for the translation': ['of'],
#  'the translation of': ['all'],
#  'translation of all': ['governmental'],
#  'of all governmental': ['proceedings'],
#  'all governmental proceedings': ['into'],
#  'governmental proceedings into': ['all'],
#  'proceedings into all': ['official'],
#  'into all official': ['languages'],
#  'all official languages': ['of'],
#  'official languages of': ['the'],
#  'languages of the': ['corresponding'],
#  'of the corresponding': ['systems'],
#  'the corresponding systems': ['of'],
#  'corresponding systems of': ['government'],
#  'systems of government': ['.'],
#  'of government .': ['However'],
#  'government . However': [','],
#  'However , most': ['other'],
#  ', most other': ['systems'],
#  'most other systems': ['depended'],
#  'other systems depended': ['on'],
#  'systems depended on': ['corpora'],
#  'depended on corpora': ['specifically'],
#  'on corpora specifically': ['developed'],
#  'corpora specifically developed': ['for'],
#  'specifically developed for': ['the'],
#  'developed for the': ['tasks'],
#  'for the tasks': ['implemented'],
#  'the tasks implemented': ['by'],
#  'tasks implemented by': ['these'],
#  'implemented by these': ['systems'],
#  'by these systems': [','],
#  'these systems ,': ['which'],
#  'systems , which': ['was'],
#  ', which was': ['('],
#  'which was (': ['and'],
#  'was ( and': ['often'],
#  '( and often': ['continues'],
#  'and often continues': ['to'],
#  'often continues to': ['be'],
#  'continues to be': [')'],
#  'to be )': ['a'],
#  'be ) a': ['major'],
#  ') a major': ['limitation'],
#  'a major limitation': ['in'],
#  'major limitation in': ['the'],
#  'limitation in the': ['success'],
#  'in the success': ['of'],
#  'the success of': ['these'],
#  'success of these': ['systems'],
#  'of these systems': ['.'],
#  'these systems .': ['As'],
#  'systems . As': ['a'],
#  '. As a': ['result'],
#  'As a result': [','],
#  'a result ,': ['a'],
#  'result , a': ['great'],
#  ', a great': ['deal'],
#  'a great deal': ['of'],
#  'great deal of': ['research'],
#  'deal of research': ['has'],
#  'of research has': ['gone'],
#  'research has gone': ['into'],
#  'has gone into': ['methods'],
#  'gone into methods': ['of'],
#  'into methods of': ['more'],
#  'methods of more': ['effectively'],
#  'of more effectively': ['learning'],
#  'more effectively learning': ['from'],
#  'effectively learning from': ['limited'],
#  'learning from limited': ['amounts'],
#  'from limited amounts': ['of'],
#  'limited amounts of': ['data'],
#  'amounts of data': ['.'],
#  'of data .': ['Recent'],
#  'data . Recent': ['research'],
#  '. Recent research': ['has'],
#  'Recent research has': ['increasingly'],
#  'research has increasingly': ['focused'],
#  'has increasingly focused': ['on'],
#  'increasingly focused on': ['unsupervised'],
#  'focused on unsupervised': ['and'],
#  'on unsupervised and': ['semi-supervised'],
#  'unsupervised and semi-supervised': ['learning'],
#  'and semi-supervised learning': ['algorithms'],
#  'semi-supervised learning algorithms': ['.'],
#  'learning algorithms .': ['Such'],
#  'algorithms . Such': ['algorithms'],
#  '. Such algorithms': ['are'],
#  'Such algorithms are': ['able'],
#  'algorithms are able': ['to'],
#  'are able to': ['learn'],
#  'able to learn': ['from'],
#  'to learn from': ['data'],
#  'learn from data': ['that'],
#  'from data that': ['has'],
#  'data that has': ['not'],
#  'that has not': ['been'],
#  'has not been': ['hand-annotated'],
#  'not been hand-annotated': ['with'],
#  'been hand-annotated with': ['the'],
#  'hand-annotated with the': ['desired'],
#  'with the desired': ['answers'],
#  'the desired answers': [','],
#  'desired answers ,': ['or'],
#  'answers , or': ['using'],
#  ', or using': ['a'],
#  'or using a': ['combination'],
#  'using a combination': ['of'],
#  'a combination of': ['annotated'],
#  'combination of annotated': ['and'],
#  'of annotated and': ['non-annotated'],
#  'annotated and non-annotated': ['data'],
#  'and non-annotated data': ['.'],
#  'non-annotated data .': ['Generally'],
#  'data . Generally': [','],
#  '. Generally ,': ['this'],
#  'Generally , this': ['task'],
#  ', this task': ['is'],
#  'this task is': ['much'],
#  'task is much': ['more'],
#  'is much more': ['difficult'],
#  'much more difficult': ['than'],
#  'more difficult than': ['supervised'],
#  'difficult than supervised': ['learning'],
#  'than supervised learning': [','],
#  'supervised learning ,': ['and'],
#  'learning , and': ['typically'],
#  ', and typically': ['produces'],
#  'and typically produces': ['less'],
#  'typically produces less': ['accurate'],
#  'produces less accurate': ['results'],
#  'less accurate results': ['for'],
#  'accurate results for': ['a'],
#  'results for a': ['given'],
#  'for a given': ['amount'],
#  'a given amount': ['of'],
#  'given amount of': ['input'],
#  'amount of input': ['data'],
#  'of input data': ['.'],
#  'data . However': [','],
#  'However , there': ['is'],
#  ', there is': ['an'],
#  'there is an': ['enormous'],
#  'is an enormous': ['amount'],
#  'an enormous amount': ['of'],
#  'enormous amount of': ['non-annotated'],
#  'amount of non-annotated': ['data'],
#  'of non-annotated data': ['available'],
#  'non-annotated data available': ['('],
#  'data available (': ['including'],
#  'available ( including': [','],
#  '( including ,': ['among'],
#  'including , among': ['other'],
#  ', among other': ['things'],
#  'among other things': [','],
#  'other things ,': ['the'],
#  'things , the': ['entire'],
#  ', the entire': ['content'],
#  'the entire content': ['of'],
#  'entire content of': ['the'],
#  'content of the': ['World'],
#  'of the World': ['Wide'],
#  'the World Wide': ['Web'],
#  'World Wide Web': [')'],
#  'Wide Web )': [','],
#  'Web ) ,': ['which'],
#  ') , which': ['can'],
#  ', which can': ['often'],
#  'which can often': ['make'],
#  'can often make': ['up'],
#  'often make up': ['for'],
#  'make up for': ['the'],
#  'up for the': ['inferior'],
#  'for the inferior': ['results'],
#  'the inferior results': ['if'],
#  'inferior results if': ['the'],
#  'results if the': ['algorithm'],
#  'if the algorithm': ['used'],
#  'the algorithm used': ['has'],
#  'algorithm used has': ['a'],
#  'used has a': ['low'],
#  'has a low': ['enough'],
#  'a low enough': ['time'],
#  'low enough time': ['complexity'],
#  'enough time complexity': ['to'],
#  'time complexity to': ['be'],
#  'complexity to be': ['practical'],
#  'to be practical': ['.'],
#  'be practical .': ['In'],
#  'practical . In': ['the'],
#  '. In the': ['2010s', 'early'],
#  'In the 2010s': [','],
#  'the 2010s ,': ['representation'],
#  '2010s , representation': ['learning'],
#  ', representation learning': ['and'],
#  'representation learning and': ['deep'],
#  'learning and deep': ['neural'],
#  'and deep neural': ['network-style'],
#  'deep neural network-style': ['machine'],
#  'neural network-style machine': ['learning'],
#  'network-style machine learning': ['methods'],
#  'machine learning methods': ['became'],
#  'learning methods became': ['widespread'],
#  'methods became widespread': ['in'],
#  'became widespread in': ['natural'],
#  'widespread in natural': ['language'],
#  'processing , due': ['in'],
#  ', due in': ['part'],
#  'due in part': ['to'],
#  'in part to': ['a'],
#  'part to a': ['flurry'],
#  'to a flurry': ['of'],
#  'a flurry of': ['results'],
#  'flurry of results': ['showing'],
#  'of results showing': ['that'],
#  'results showing that': ['such'],
#  'showing that such': ['techniques'],
#  'that such techniques': ['['],
#  'such techniques [': ['4'],
#  'techniques [ 4': [']'],
#  '[ 4 ]': ['['],
#  '4 ] [': ['5'],
#  '] [ 5': [']'],
#  '[ 5 ]': ['can'],
#  '5 ] can': ['achieve'],
#  '] can achieve': ['state-of-the-art'],
#  'can achieve state-of-the-art': ['results'],
#  'achieve state-of-the-art results': ['in'],
#  'state-of-the-art results in': ['many'],
#  'results in many': ['natural'],
#  'in many natural': ['language'],
#  'many natural language': ['tasks'],
#  'natural language tasks': [','],
#  'language tasks ,': ['for'],
#  'tasks , for': ['example'],
#  'for example in': ['language'],
#  'example in language': ['modeling'],
#  'in language modeling': [','],
#  'language modeling ,': ['['],
#  'modeling , [': ['6'],
#  ', [ 6': [']'],
#  '[ 6 ]': ['parsing'],
#  '6 ] parsing': [','],
#  '] parsing ,': ['['],
#  'parsing , [': ['7'],
#  ', [ 7': [']'],
#  '[ 7 ]': ['['],
#  '7 ] [': ['8'],
#  '] [ 8': [']'],
#  '[ 8 ]': ['and'],
#  '8 ] and': ['many'],
#  '] and many': ['others'],
#  'and many others': ['.'],
#  'many others .': ['Popular'],
#  'others . Popular': ['techniques'],
#  '. Popular techniques': ['include'],
#  'Popular techniques include': ['the'],
#  'techniques include the': ['use'],
#  'include the use': ['of'],
#  'use of word': ['embeddings'],
#  'of word embeddings': ['to'],
#  'word embeddings to': ['capture'],
#  'embeddings to capture': ['semantic'],
#  'to capture semantic': ['properties'],
#  'capture semantic properties': ['of'],
#  'semantic properties of': ['words'],
#  'properties of words': [','],
#  'of words ,': ['and'],
#  'words , and': ['an'],
#  ', and an': ['increase'],
#  'and an increase': ['in'],
#  'an increase in': ['end-to-end'],
#  'increase in end-to-end': ['learning'],
#  'in end-to-end learning': ['of'],
#  'end-to-end learning of': ['a'],
#  'learning of a': ['higher-level'],
#  'of a higher-level': ['task'],
#  'a higher-level task': ['('],
#  'higher-level task (': ['e.g.'],
#  'task ( e.g.': [','],
#  '( e.g. ,': ['question', 'part-of-speech'],
#  'e.g. , question': ['answering'],
#  ', question answering': [')'],
#  'question answering )': ['instead'],
#  'answering ) instead': ['of'],
#  ') instead of': ['relying'],
#  'instead of relying': ['on'],
#  'of relying on': ['a'],
#  'relying on a': ['pipeline'],
#  'on a pipeline': ['of'],
#  'a pipeline of': ['separate'],
#  'pipeline of separate': ['intermediate'],
#  'of separate intermediate': ['tasks'],
#  'separate intermediate tasks': ['('],
#  'intermediate tasks (': ['e.g.'],
#  'tasks ( e.g.': [','],
#  'e.g. , part-of-speech': ['tagging'],
#  'part-of-speech tagging and': ['dependency'],
#  'tagging and dependency': ['parsing'],
#  'and dependency parsing': [')'],
#  'dependency parsing )': ['.'],
#  'parsing ) .': ['In'],
#  ') . In': ['some', 'the'],
#  '. In some': ['areas'],
#  'In some areas': [','],
#  ...}

# %% [markdown]
# ### Step 5: Testing the N-Grams by generating a sequence

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) generally started in the 1950s , although work can be found from earlier periods . In 1950 , Alan Turing published an article titled `` Computing Machinery and Intelligence '' which proposed what is now called the Turing test as a criterion of intelligence . The Georgetown

# %% [markdown]
# ### Building a N-Grams Model with **N-Grams = 4**

# %%
ngrams = {}
words = 4

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    None

ngrams
# Out:
# Natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) is
# NLP ) is a
# ) is a subfield
# is a subfield of
# a subfield of linguistics
# subfield of linguistics ,
# of linguistics , computer
# linguistics , computer science
# , computer science ,
# computer science , information
# science , information engineering
# , information engineering ,
# information engineering , and
# engineering , and artificial
# , and artificial intelligence
# and artificial intelligence concerned
# artificial intelligence concerned with
# intelligence concerned with the
# concerned with the interactions
# with the interactions between
# the interactions between computers
# interactions between computers and
# between computers and human
# computers and human (
# and human ( natural
# human ( natural )
# ( natural ) languages
# natural ) languages ,
# ) languages , in
# languages , in particular
# , in particular how
# in particular how to
# particular how to program
# how to program computers
# to program computers to
# program computers to process
# computers to process and
# to process and analyze
# process and analyze large
# and analyze large amounts
# analyze large amounts of
# large amounts of natural
# amounts of natural language
# of natural language data
# natural language data .
# language data . Challenges
# data . Challenges in
# . Challenges in natural
# Challenges in natural language
# in natural language processing
# natural language processing frequently
# language processing frequently involve
# processing frequently involve speech
# frequently involve speech recognition
# involve speech recognition ,
# speech recognition , natural
# recognition , natural language
# , natural language understanding
# natural language understanding ,
# language understanding , and
# understanding , and natural
# , and natural language
# and natural language generation
# natural language generation .
# language generation . The
# generation . The history
# . The history of
# The history of natural
# history of natural language
# of natural language processing
# natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) generally
# NLP ) generally started
# ) generally started in
# generally started in the
# started in the 1950s
# in the 1950s ,
# the 1950s , although
# 1950s , although work
# , although work can
# although work can be
# work can be found
# can be found from
# be found from earlier
# found from earlier periods
# from earlier periods .
# earlier periods . In
# periods . In 1950
# . In 1950 ,
# In 1950 , Alan
# 1950 , Alan Turing
# , Alan Turing published
# Alan Turing published an
# Turing published an article
# published an article titled
# an article titled ``
# article titled `` Computing
# titled `` Computing Machinery
# `` Computing Machinery and
# Computing Machinery and Intelligence
# Machinery and Intelligence ''
# and Intelligence '' which
# Intelligence '' which proposed
# '' which proposed what
# which proposed what is
# proposed what is now
# what is now called
# is now called the
# now called the Turing
# called the Turing test
# the Turing test as
# Turing test as a
# test as a criterion
# as a criterion of
# a criterion of intelligence
# criterion of intelligence .
# of intelligence . The
# intelligence . The Georgetown
# . The Georgetown experiment
# The Georgetown experiment in
# Georgetown experiment in 1954
# experiment in 1954 involved
# in 1954 involved fully
# 1954 involved fully automatic
# involved fully automatic translation
# fully automatic translation of
# automatic translation of more
# translation of more than
# of more than sixty
# more than sixty Russian
# than sixty Russian sentences
# sixty Russian sentences into
# Russian sentences into English
# sentences into English .
# into English . The
# English . The authors
# . The authors claimed
# The authors claimed that
# authors claimed that within
# claimed that within three
# that within three or
# within three or five
# three or five years
# or five years ,
# five years , machine
# years , machine translation
# , machine translation would
# machine translation would be
# translation would be a
# would be a solved
# be a solved problem
# a solved problem .
# solved problem . [
# problem . [ 2
# . [ 2 ]
# [ 2 ] However
# 2 ] However ,
# ] However , real
# However , real progress
# , real progress was
# real progress was much
# progress was much slower
# was much slower ,
# much slower , and
# slower , and after
# , and after the
# and after the ALPAC
# after the ALPAC report
# the ALPAC report in
# ALPAC report in 1966
# report in 1966 ,
# in 1966 , which
# 1966 , which found
# , which found that
# which found that ten-year-long
# found that ten-year-long research
# that ten-year-long research had
# ten-year-long research had failed
# research had failed to
# had failed to fulfill
# failed to fulfill the
# to fulfill the expectations
# fulfill the expectations ,
# the expectations , funding
# expectations , funding for
# , funding for machine
# funding for machine translation
# for machine translation was
# machine translation was dramatically
# translation was dramatically reduced
# was dramatically reduced .
# dramatically reduced . Little
# reduced . Little further
# . Little further research
# Little further research in
# further research in machine
# research in machine translation
# in machine translation was
# machine translation was conducted
# translation was conducted until
# was conducted until the
# conducted until the late
# until the late 1980s
# the late 1980s ,
# late 1980s , when
# 1980s , when the
# , when the first
# when the first statistical
# the first statistical machine
# first statistical machine translation
# statistical machine translation systems
# machine translation systems were
# translation systems were developed
# systems were developed .
# were developed . Some
# developed . Some notably
# . Some notably successful
# Some notably successful natural
# notably successful natural language
# successful natural language processing
# natural language processing systems
# language processing systems developed
# processing systems developed in
# systems developed in the
# developed in the 1960s
# in the 1960s were
# the 1960s were SHRDLU
# 1960s were SHRDLU ,
# were SHRDLU , a
# SHRDLU , a natural
# , a natural language
# a natural language system
# natural language system working
# language system working in
# system working in restricted
# working in restricted ``
# in restricted `` blocks
# restricted `` blocks worlds
# `` blocks worlds ''
# blocks worlds '' with
# worlds '' with restricted
# '' with restricted vocabularies
# with restricted vocabularies ,
# restricted vocabularies , and
# vocabularies , and ELIZA
# , and ELIZA ,
# and ELIZA , a
# ELIZA , a simulation
# , a simulation of
# a simulation of a
# simulation of a Rogerian
# of a Rogerian psychotherapist
# a Rogerian psychotherapist ,
# Rogerian psychotherapist , written
# psychotherapist , written by
# , written by Joseph
# written by Joseph Weizenbaum
# by Joseph Weizenbaum between
# Joseph Weizenbaum between 1964
# Weizenbaum between 1964 and
# between 1964 and 1966
# 1964 and 1966 .
# and 1966 . Using
# 1966 . Using almost
# . Using almost no
# Using almost no information
# almost no information about
# no information about human
# information about human thought
# about human thought or
# human thought or emotion
# thought or emotion ,
# or emotion , ELIZA
# emotion , ELIZA sometimes
# , ELIZA sometimes provided
# ELIZA sometimes provided a
# sometimes provided a startlingly
# provided a startlingly human-like
# a startlingly human-like interaction
# startlingly human-like interaction .
# human-like interaction . When
# interaction . When the
# . When the ``
# When the `` patient
# the `` patient ''
# `` patient '' exceeded
# patient '' exceeded the
# '' exceeded the very
# exceeded the very small
# the very small knowledge
# very small knowledge base
# small knowledge base ,
# knowledge base , ELIZA
# base , ELIZA might
# , ELIZA might provide
# ELIZA might provide a
# might provide a generic
# provide a generic response
# a generic response ,
# generic response , for
# response , for example
# , for example ,
# for example , responding
# example , responding to
# , responding to ``
# responding to `` My
# to `` My head
# `` My head hurts
# My head hurts ''
# head hurts '' with
# hurts '' with ``
# '' with `` Why
# with `` Why do
# `` Why do you
# Why do you say
# do you say your
# you say your head
# say your head hurts
# your head hurts ?
# head hurts ? ''
# hurts ? '' .
# ? '' . During
# '' . During the
# . During the 1970s
# During the 1970s ,
# the 1970s , many
# 1970s , many programmers
# , many programmers began
# many programmers began to
# programmers began to write
# began to write ``
# to write `` conceptual
# write `` conceptual ontologies
# `` conceptual ontologies ''
# conceptual ontologies '' ,
# ontologies '' , which
# '' , which structured
# , which structured real-world
# which structured real-world information
# structured real-world information into
# real-world information into computer-understandable
# information into computer-understandable data
# into computer-understandable data .
# computer-understandable data . Examples
# data . Examples are
# . Examples are MARGIE
# Examples are MARGIE (
# are MARGIE ( Schank
# MARGIE ( Schank ,
# ( Schank , 1975
# Schank , 1975 )
# , 1975 ) ,
# 1975 ) , SAM
# ) , SAM (
# , SAM ( Cullingford
# SAM ( Cullingford ,
# ( Cullingford , 1978
# Cullingford , 1978 )
# , 1978 ) ,
# 1978 ) , PAM
# ) , PAM (
# , PAM ( Wilensky
# PAM ( Wilensky ,
# ( Wilensky , 1978
# Wilensky , 1978 )
# , 1978 ) ,
# 1978 ) , TaleSpin
# ) , TaleSpin (
# , TaleSpin ( Meehan
# TaleSpin ( Meehan ,
# ( Meehan , 1976
# Meehan , 1976 )
# , 1976 ) ,
# 1976 ) , QUALM
# ) , QUALM (
# , QUALM ( Lehnert
# QUALM ( Lehnert ,
# ( Lehnert , 1977
# Lehnert , 1977 )
# , 1977 ) ,
# 1977 ) , Politics
# ) , Politics (
# , Politics ( Carbonell
# Politics ( Carbonell ,
# ( Carbonell , 1979
# Carbonell , 1979 )
# , 1979 ) ,
# 1979 ) , and
# ) , and Plot
# , and Plot Units
# and Plot Units (
# Plot Units ( Lehnert
# Units ( Lehnert 1981
# ( Lehnert 1981 )
# Lehnert 1981 ) .
# 1981 ) . During
# ) . During this
# . During this time
# During this time ,
# this time , many
# time , many chatterbots
# , many chatterbots were
# many chatterbots were written
# chatterbots were written including
# were written including PARRY
# written including PARRY ,
# including PARRY , Racter
# PARRY , Racter ,
# , Racter , and
# Racter , and Jabberwacky
# , and Jabberwacky .
# and Jabberwacky . Up
# Jabberwacky . Up to
# . Up to the
# Up to the 1980s
# to the 1980s ,
# the 1980s , most
# 1980s , most natural
# , most natural language
# most natural language processing
# natural language processing systems
# language processing systems were
# processing systems were based
# systems were based on
# were based on complex
# based on complex sets
# on complex sets of
# complex sets of hand-written
# sets of hand-written rules
# of hand-written rules .
# hand-written rules . Starting
# rules . Starting in
# . Starting in the
# Starting in the late
# in the late 1980s
# the late 1980s ,
# late 1980s , however
# 1980s , however ,
# , however , there
# however , there was
# , there was a
# there was a revolution
# was a revolution in
# a revolution in natural
# revolution in natural language
# in natural language processing
# natural language processing with
# language processing with the
# processing with the introduction
# with the introduction of
# the introduction of machine
# introduction of machine learning
# of machine learning algorithms
# machine learning algorithms for
# learning algorithms for language
# algorithms for language processing
# for language processing .
# language processing . This
# processing . This was
# . This was due
# This was due to
# was due to both
# due to both the
# to both the steady
# both the steady increase
# the steady increase in
# steady increase in computational
# increase in computational power
# in computational power (
# computational power ( see
# power ( see Moore
# ( see Moore 's
# see Moore 's law
# Moore 's law )
# 's law ) and
# law ) and the
# ) and the gradual
# and the gradual lessening
# the gradual lessening of
# gradual lessening of the
# lessening of the dominance
# of the dominance of
# the dominance of Chomskyan
# dominance of Chomskyan theories
# of Chomskyan theories of
# Chomskyan theories of linguistics
# theories of linguistics (
# of linguistics ( e.g
# linguistics ( e.g .
# ( e.g . transformational
# e.g . transformational grammar
# . transformational grammar )
# transformational grammar ) ,
# grammar ) , whose
# ) , whose theoretical
# , whose theoretical underpinnings
# whose theoretical underpinnings discouraged
# theoretical underpinnings discouraged the
# underpinnings discouraged the sort
# discouraged the sort of
# the sort of corpus
# sort of corpus linguistics
# of corpus linguistics that
# corpus linguistics that underlies
# linguistics that underlies the
# that underlies the machine-learning
# underlies the machine-learning approach
# the machine-learning approach to
# machine-learning approach to language
# approach to language processing
# to language processing .
# language processing . [
# processing . [ 3
# . [ 3 ]
# [ 3 ] Some
# 3 ] Some of
# ] Some of the
# Some of the earliest-used
# of the earliest-used machine
# the earliest-used machine learning
# earliest-used machine learning algorithms
# machine learning algorithms ,
# learning algorithms , such
# algorithms , such as
# , such as decision
# such as decision trees
# as decision trees ,
# decision trees , produced
# trees , produced systems
# , produced systems of
# produced systems of hard
# systems of hard if-then
# of hard if-then rules
# hard if-then rules similar
# if-then rules similar to
# rules similar to existing
# similar to existing hand-written
# to existing hand-written rules
# existing hand-written rules .
# hand-written rules . However
# rules . However ,
# . However , part-of-speech
# However , part-of-speech tagging
# , part-of-speech tagging introduced
# part-of-speech tagging introduced the
# tagging introduced the use
# introduced the use of
# the use of hidden
# use of hidden Markov
# of hidden Markov models
# hidden Markov models to
# Markov models to natural
# models to natural language
# to natural language processing
# natural language processing ,
# language processing , and
# processing , and increasingly
# , and increasingly ,
# and increasingly , research
# increasingly , research has
# , research has focused
# research has focused on
# has focused on statistical
# focused on statistical models
# on statistical models ,
# statistical models , which
# models , which make
# , which make soft
# which make soft ,
# make soft , probabilistic
# soft , probabilistic decisions
# , probabilistic decisions based
# probabilistic decisions based on
# decisions based on attaching
# based on attaching real-valued
# on attaching real-valued weights
# attaching real-valued weights to
# real-valued weights to the
# weights to the features
# to the features making
# the features making up
# features making up the
# making up the input
# up the input data
# the input data .
# input data . The
# data . The cache
# . The cache language
# The cache language models
# cache language models upon
# language models upon which
# models upon which many
# upon which many speech
# which many speech recognition
# many speech recognition systems
# speech recognition systems now
# recognition systems now rely
# systems now rely are
# now rely are examples
# rely are examples of
# are examples of such
# examples of such statistical
# of such statistical models
# such statistical models .
# statistical models . Such
# models . Such models
# . Such models are
# Such models are generally
# models are generally more
# are generally more robust
# generally more robust when
# more robust when given
# robust when given unfamiliar
# when given unfamiliar input
# given unfamiliar input ,
# unfamiliar input , especially
# input , especially input
# , especially input that
# especially input that contains
# input that contains errors
# that contains errors (
# contains errors ( as
# errors ( as is
# ( as is very
# as is very common
# is very common for
# very common for real-world
# common for real-world data
# for real-world data )
# real-world data ) ,
# data ) , and
# ) , and produce
# , and produce more
# and produce more reliable
# produce more reliable results
# more reliable results when
# reliable results when integrated
# results when integrated into
# when integrated into a
# integrated into a larger
# into a larger system
# a larger system comprising
# larger system comprising multiple
# system comprising multiple subtasks
# comprising multiple subtasks .
# multiple subtasks . Many
# subtasks . Many of
# . Many of the
# Many of the notable
# of the notable early
# the notable early successes
# notable early successes occurred
# early successes occurred in
# successes occurred in the
# occurred in the field
# in the field of
# the field of machine
# field of machine translation
# of machine translation ,
# machine translation , due
# translation , due especially
# , due especially to
# due especially to work
# especially to work at
# to work at IBM
# work at IBM Research
# at IBM Research ,
# IBM Research , where
# Research , where successively
# , where successively more
# where successively more complicated
# successively more complicated statistical
# more complicated statistical models
# complicated statistical models were
# statistical models were developed
# models were developed .
# were developed . These
# developed . These systems
# . These systems were
# These systems were able
# systems were able to
# were able to take
# able to take advantage
# to take advantage of
# take advantage of existing
# advantage of existing multilingual
# of existing multilingual textual
# existing multilingual textual corpora
# multilingual textual corpora that
# textual corpora that had
# corpora that had been
# that had been produced
# had been produced by
# been produced by the
# produced by the Parliament
# by the Parliament of
# the Parliament of Canada
# Parliament of Canada and
# of Canada and the
# Canada and the European
# and the European Union
# the European Union as
# European Union as a
# Union as a result
# as a result of
# a result of laws
# result of laws calling
# of laws calling for
# laws calling for the
# calling for the translation
# for the translation of
# the translation of all
# translation of all governmental
# of all governmental proceedings
# all governmental proceedings into
# governmental proceedings into all
# proceedings into all official
# into all official languages
# all official languages of
# official languages of the
# languages of the corresponding
# of the corresponding systems
# the corresponding systems of
# corresponding systems of government
# systems of government .
# of government . However
# government . However ,
# . However , most
# However , most other
# , most other systems
# most other systems depended
# other systems depended on
# systems depended on corpora
# depended on corpora specifically
# on corpora specifically developed
# corpora specifically developed for
# specifically developed for the
# developed for the tasks
# for the tasks implemented
# the tasks implemented by
# tasks implemented by these
# implemented by these systems
# by these systems ,
# these systems , which
# systems , which was
# , which was (
# which was ( and
# was ( and often
# ( and often continues
# and often continues to
# often continues to be
# continues to be )
# to be ) a
# be ) a major
# ) a major limitation
# a major limitation in
# major limitation in the
# limitation in the success
# in the success of
# the success of these
# success of these systems
# of these systems .
# these systems . As
# systems . As a
# . As a result
# As a result ,
# a result , a
# result , a great
# , a great deal
# a great deal of
# great deal of research
# deal of research has
# of research has gone
# research has gone into
# has gone into methods
# gone into methods of
# into methods of more
# methods of more effectively
# of more effectively learning
# more effectively learning from
# effectively learning from limited
# learning from limited amounts
# from limited amounts of
# limited amounts of data
# amounts of data .
# of data . Recent
# data . Recent research
# . Recent research has
# Recent research has increasingly
# research has increasingly focused
# has increasingly focused on
# increasingly focused on unsupervised
# focused on unsupervised and
# on unsupervised and semi-supervised
# unsupervised and semi-supervised learning
# and semi-supervised learning algorithms
# semi-supervised learning algorithms .
# learning algorithms . Such
# algorithms . Such algorithms
# . Such algorithms are
# Such algorithms are able
# algorithms are able to
# are able to learn
# able to learn from
# to learn from data
# learn from data that
# from data that has
# data that has not
# that has not been
# has not been hand-annotated
# not been hand-annotated with
# been hand-annotated with the
# hand-annotated with the desired
# with the desired answers
# the desired answers ,
# desired answers , or
# answers , or using
# , or using a
# or using a combination
# using a combination of
# a combination of annotated
# combination of annotated and
# of annotated and non-annotated
# annotated and non-annotated data
# and non-annotated data .
# non-annotated data . Generally
# data . Generally ,
# . Generally , this
# Generally , this task
# , this task is
# this task is much
# task is much more
# is much more difficult
# much more difficult than
# more difficult than supervised
# difficult than supervised learning
# than supervised learning ,
# supervised learning , and
# learning , and typically
# , and typically produces
# and typically produces less
# typically produces less accurate
# produces less accurate results
# less accurate results for
# accurate results for a
# results for a given
# for a given amount
# a given amount of
# given amount of input
# amount of input data
# of input data .
# input data . However
# data . However ,
# . However , there
# However , there is
# , there is an
# there is an enormous
# is an enormous amount
# an enormous amount of
# enormous amount of non-annotated
# amount of non-annotated data
# of non-annotated data available
# non-annotated data available (
# data available ( including
# available ( including ,
# ( including , among
# including , among other
# , among other things
# among other things ,
# other things , the
# things , the entire
# , the entire content
# the entire content of
# entire content of the
# content of the World
# of the World Wide
# the World Wide Web
# World Wide Web )
# Wide Web ) ,
# Web ) , which
# ) , which can
# , which can often
# which can often make
# can often make up
# often make up for
# make up for the
# up for the inferior
# for the inferior results
# the inferior results if
# inferior results if the
# results if the algorithm
# if the algorithm used
# the algorithm used has
# algorithm used has a
# used has a low
# has a low enough
# a low enough time
# low enough time complexity
# enough time complexity to
# time complexity to be
# complexity to be practical
# to be practical .
# be practical . In
# practical . In the
# . In the 2010s
# In the 2010s ,
# the 2010s , representation
# 2010s , representation learning
# , representation learning and
# representation learning and deep
# learning and deep neural
# and deep neural network-style
# deep neural network-style machine
# neural network-style machine learning
# network-style machine learning methods
# machine learning methods became
# learning methods became widespread
# methods became widespread in
# became widespread in natural
# widespread in natural language
# in natural language processing
# natural language processing ,
# language processing , due
# processing , due in
# , due in part
# due in part to
# in part to a
# part to a flurry
# to a flurry of
# a flurry of results
# flurry of results showing
# of results showing that
# results showing that such
# showing that such techniques
# that such techniques [
# such techniques [ 4
# techniques [ 4 ]
# [ 4 ] [
# 4 ] [ 5
# ] [ 5 ]
# [ 5 ] can
# 5 ] can achieve
# ] can achieve state-of-the-art
# can achieve state-of-the-art results
# achieve state-of-the-art results in
# state-of-the-art results in many
# results in many natural
# in many natural language
# many natural language tasks
# natural language tasks ,
# language tasks , for
# tasks , for example
# , for example in
# for example in language
# example in language modeling
# in language modeling ,
# language modeling , [
# modeling , [ 6
# , [ 6 ]
# [ 6 ] parsing
# 6 ] parsing ,
# ] parsing , [
# parsing , [ 7
# , [ 7 ]
# [ 7 ] [
# 7 ] [ 8
# ] [ 8 ]
# [ 8 ] and
# 8 ] and many
# ] and many others
# and many others .
# many others . Popular
# others . Popular techniques
# . Popular techniques include
# Popular techniques include the
# techniques include the use
# include the use of
# the use of word
# use of word embeddings
# of word embeddings to
# word embeddings to capture
# embeddings to capture semantic
# to capture semantic properties
# capture semantic properties of
# semantic properties of words
# properties of words ,
# of words , and
# words , and an
# , and an increase
# and an increase in
# an increase in end-to-end
# increase in end-to-end learning
# in end-to-end learning of
# end-to-end learning of a
# learning of a higher-level
# of a higher-level task
# a higher-level task (
# higher-level task ( e.g.
# task ( e.g. ,
# ( e.g. , question
# e.g. , question answering
# , question answering )
# question answering ) instead
# answering ) instead of
# ) instead of relying
# instead of relying on
# of relying on a
# relying on a pipeline
# on a pipeline of
# a pipeline of separate
# pipeline of separate intermediate
# of separate intermediate tasks
# separate intermediate tasks (
# intermediate tasks ( e.g.
# tasks ( e.g. ,
# ( e.g. , part-of-speech
# e.g. , part-of-speech tagging
# , part-of-speech tagging and
# part-of-speech tagging and dependency
# tagging and dependency parsing
# and dependency parsing )
# dependency parsing ) .
# parsing ) . In
# ) . In some
# . In some areas
# In some areas ,
# some areas , this
# areas , this shift
# , this shift has
# this shift has entailed
# shift has entailed substantial
# has entailed substantial changes
# entailed substantial changes in
# substantial changes in how
# changes in how NLP
# in how NLP systems
# how NLP systems are
# NLP systems are designed
# systems are designed ,
# are designed , such
# designed , such that
# , such that deep
# such that deep neural
# that deep neural network-based
# deep neural network-based approaches
# neural network-based approaches may
# network-based approaches may be
# approaches may be viewed
# may be viewed as
# be viewed as a
# viewed as a new
# as a new paradigm
# a new paradigm distinct
# new paradigm distinct from
# paradigm distinct from statistical
# distinct from statistical natural
# from statistical natural language
# statistical natural language processing
# natural language processing .
# language processing . For
# processing . For instance
# . For instance ,
# For instance , the
# instance , the term
# , the term neural
# the term neural machine
# term neural machine translation
# neural machine translation (
# machine translation ( NMT
# translation ( NMT )
# ( NMT ) emphasizes
# NMT ) emphasizes the
# ) emphasizes the fact
# emphasizes the fact that
# the fact that deep
# fact that deep learning-based
# that deep learning-based approaches
# deep learning-based approaches to
# learning-based approaches to machine
# approaches to machine translation
# to machine translation directly
# machine translation directly learn
# translation directly learn sequence-to-sequence
# directly learn sequence-to-sequence transformations
# learn sequence-to-sequence transformations ,
# sequence-to-sequence transformations , obviating
# transformations , obviating the
# , obviating the need
# obviating the need for
# the need for intermediate
# need for intermediate steps
# for intermediate steps such
# intermediate steps such as
# steps such as word
# such as word alignment
# as word alignment and
# word alignment and language
# alignment and language modeling
# and language modeling that
# language modeling that were
# modeling that were used
# that were used in
# were used in statistical
# used in statistical machine
# in statistical machine translation
# statistical machine translation (
# machine translation ( SMT
# translation ( SMT )
# ( SMT ) .
# SMT ) . In
# ) . In the
# . In the early
# In the early days
# the early days ,
# early days , many
# days , many language-processing
# , many language-processing systems
# many language-processing systems were
# language-processing systems were designed
# systems were designed by
# were designed by hand-coding
# designed by hand-coding a
# by hand-coding a set
# hand-coding a set of
# a set of rules
# set of rules ,
# of rules , [
# rules , [ 9
# , [ 9 ]
# [ 9 ] [
# 9 ] [ 10
# ] [ 10 ]
# [ 10 ] e.g
# 10 ] e.g .
# ] e.g . by
# e.g . by writing
# . by writing grammars
# by writing grammars or
# writing grammars or devising
# grammars or devising heuristic
# or devising heuristic rules
# devising heuristic rules for
# heuristic rules for stemming
# rules for stemming .
# for stemming . However
# stemming . However ,
# . However , this
# However , this is
# , this is rarely
# this is rarely robust
# is rarely robust to
# rarely robust to natural
# robust to natural language
# to natural language variation
# natural language variation .
# language variation . Since
# variation . Since the
# . Since the so-called
# Since the so-called ``
# the so-called `` statistical
# so-called `` statistical revolution
# `` statistical revolution ''
# statistical revolution '' [
# revolution '' [ 11
# '' [ 11 ]
# [ 11 ] [
# 11 ] [ 12
# ] [ 12 ]
# [ 12 ] in
# 12 ] in the
# ] in the late
# in the late 1980s
# the late 1980s and
# late 1980s and mid
# 1980s and mid 1990s
# and mid 1990s ,
# mid 1990s , much
# 1990s , much natural
# , much natural language
# much natural language processing
# natural language processing research
# language processing research has
# processing research has relied
# research has relied heavily
# has relied heavily on
# relied heavily on machine
# heavily on machine learning
# on machine learning .
# machine learning . The
# learning . The machine-learning
# . The machine-learning paradigm
# The machine-learning paradigm calls
# machine-learning paradigm calls instead
# paradigm calls instead for
# calls instead for using
# instead for using statistical
# for using statistical inference
# using statistical inference to
# statistical inference to automatically
# inference to automatically learn
# to automatically learn such
# automatically learn such rules
# learn such rules through
# such rules through the
# rules through the analysis
# through the analysis of
# the analysis of large
# analysis of large corpora
# of large corpora of
# large corpora of typical
# corpora of typical real-world
# of typical real-world examples
# typical real-world examples (
# real-world examples ( a
# examples ( a corpus
# ( a corpus (
# a corpus ( plural
# corpus ( plural ,
# ( plural , ``
# plural , `` corpora
# , `` corpora ''
# `` corpora '' )
# corpora '' ) is
# '' ) is a
# ) is a set
# is a set of
# a set of documents
# set of documents ,
# of documents , possibly
# documents , possibly with
# , possibly with human
# possibly with human or
# with human or computer
# human or computer annotations
# or computer annotations )
# computer annotations ) .
# annotations ) . Many
# ) . Many different
# . Many different classes
# Many different classes of
# different classes of machine-learning
# classes of machine-learning algorithms
# of machine-learning algorithms have
# machine-learning algorithms have been
# algorithms have been applied
# have been applied to
# been applied to natural-language-processing
# applied to natural-language-processing tasks
# to natural-language-processing tasks .
# natural-language-processing tasks . These
# tasks . These algorithms
# . These algorithms take
# These algorithms take as
# algorithms take as input
# take as input a
# as input a large
# input a large set
# a large set of
# large set of ``
# set of `` features
# of `` features ''
# `` features '' that
# features '' that are
# '' that are generated
# that are generated from
# are generated from the
# generated from the input
# from the input data
# the input data .
# input data . Some
# data . Some of
# . Some of the
# Some of the earliest-used
# of the earliest-used algorithms
# the earliest-used algorithms ,
# earliest-used algorithms , such
# algorithms , such as
# , such as decision
# such as decision trees
# as decision trees ,
# decision trees , produced
# trees , produced systems
# , produced systems of
# produced systems of hard
# systems of hard if-then
# of hard if-then rules
# hard if-then rules similar
# if-then rules similar to
# rules similar to the
# similar to the systems
# to the systems of
# the systems of hand-written
# systems of hand-written rules
# of hand-written rules that
# hand-written rules that were
# rules that were then
# that were then common
# were then common .
# then common . Increasingly
# common . Increasingly ,
# . Increasingly , however
# Increasingly , however ,
# , however , research
# however , research has
# , research has focused
# research has focused on
# has focused on statistical
# focused on statistical models
# on statistical models ,
# statistical models , which
# models , which make
# , which make soft
# which make soft ,
# make soft , probabilistic
# soft , probabilistic decisions
# , probabilistic decisions based
# probabilistic decisions based on
# decisions based on attaching
# based on attaching real-valued
# on attaching real-valued weights
# attaching real-valued weights to
# real-valued weights to each
# weights to each input
# to each input feature
# each input feature .
# input feature . Such
# feature . Such models
# . Such models have
# Such models have the
# models have the advantage
# have the advantage that
# the advantage that they
# advantage that they can
# that they can express
# they can express the
# can express the relative
# express the relative certainty
# the relative certainty of
# relative certainty of many
# certainty of many different
# of many different possible
# many different possible answers
# different possible answers rather
# possible answers rather than
# answers rather than only
# rather than only one
# than only one ,
# only one , producing
# one , producing more
# , producing more reliable
# producing more reliable results
# more reliable results when
# reliable results when such
# results when such a
# when such a model
# such a model is
# a model is included
# model is included as
# is included as a
# included as a component
# as a component of
# a component of a
# component of a larger
# of a larger system
# a larger system .
# larger system . Systems
# system . Systems based
# . Systems based on
# Systems based on machine-learning
# based on machine-learning algorithms
# on machine-learning algorithms have
# machine-learning algorithms have many
# algorithms have many advantages
# have many advantages over
# many advantages over hand-produced
# advantages over hand-produced rules
# over hand-produced rules :
# hand-produced rules : The
# rules : The following
# : The following is
# The following is a
# following is a list
# is a list of
# a list of some
# list of some of
# of some of the
# some of the most
# of the most commonly
# the most commonly researched
# most commonly researched tasks
# commonly researched tasks in
# researched tasks in natural
# tasks in natural language
# in natural language processing
# natural language processing .
# language processing . Some
# processing . Some of
# . Some of these
# Some of these tasks
# of these tasks have
# these tasks have direct
# tasks have direct real-world
# have direct real-world applications
# direct real-world applications ,
# real-world applications , while
# applications , while others
# , while others more
# while others more commonly
# others more commonly serve
# more commonly serve as
# commonly serve as subtasks
# serve as subtasks that
# as subtasks that are
# subtasks that are used
# that are used to
# are used to aid
# used to aid in
# to aid in solving
# aid in solving larger
# in solving larger tasks
# solving larger tasks .
# larger tasks . Though
# tasks . Though natural
# . Though natural language
# Though natural language processing
# natural language processing tasks
# language processing tasks are
# processing tasks are closely
# tasks are closely intertwined
# are closely intertwined ,
# closely intertwined , they
# intertwined , they are
# , they are frequently
# they are frequently subdivided
# are frequently subdivided into
# frequently subdivided into categories
# subdivided into categories for
# into categories for convenience
# categories for convenience .
# for convenience . A
# convenience . A coarse
# . A coarse division
# A coarse division is
# coarse division is given
# division is given below
# is given below .
# given below . The
# below . The first
# . The first published
# The first published work
# first published work by
# published work by an
# work by an artificial
# by an artificial intelligence
# an artificial intelligence was
# artificial intelligence was published
# intelligence was published in
# was published in 2018
# published in 2018 ,
# in 2018 , 1
# 2018 , 1 the
# , 1 the Road
# 1 the Road ,
# the Road , marketed
# Road , marketed as
# , marketed as a
# marketed as a novel
# as a novel ,
# a novel , contains
# novel , contains sixty
# , contains sixty million
# contains sixty million words
# {'Natural language processing (': ['NLP'],
#  'language processing ( NLP': [')', ')'],
#  'processing ( NLP )': ['is', 'generally'],
#  '( NLP ) is': ['a'],
#  'NLP ) is a': ['subfield'],
#  ') is a subfield': ['of'],
#  'is a subfield of': ['linguistics'],
#  'a subfield of linguistics': [','],
#  'subfield of linguistics ,': ['computer'],
#  'of linguistics , computer': ['science'],
#  'linguistics , computer science': [','],
#  ', computer science ,': ['information'],
#  'computer science , information': ['engineering'],
#  'science , information engineering': [','],
#  ', information engineering ,': ['and'],
#  'information engineering , and': ['artificial'],
#  'engineering , and artificial': ['intelligence'],
#  ', and artificial intelligence': ['concerned'],
#  'and artificial intelligence concerned': ['with'],
#  'artificial intelligence concerned with': ['the'],
#  'intelligence concerned with the': ['interactions'],
#  'concerned with the interactions': ['between'],
#  'with the interactions between': ['computers'],
#  'the interactions between computers': ['and'],
#  'interactions between computers and': ['human'],
#  'between computers and human': ['('],
#  'computers and human (': ['natural'],
#  'and human ( natural': [')'],
#  'human ( natural )': ['languages'],
#  '( natural ) languages': [','],
#  'natural ) languages ,': ['in'],
#  ') languages , in': ['particular'],
#  'languages , in particular': ['how'],
#  ', in particular how': ['to'],
#  'in particular how to': ['program'],
#  'particular how to program': ['computers'],
#  'how to program computers': ['to'],
#  'to program computers to': ['process'],
#  'program computers to process': ['and'],
#  'computers to process and': ['analyze'],
#  'to process and analyze': ['large'],
#  'process and analyze large': ['amounts'],
#  'and analyze large amounts': ['of'],
#  'analyze large amounts of': ['natural'],
#  'large amounts of natural': ['language'],
#  'amounts of natural language': ['data'],
#  'of natural language data': ['.'],
#  'natural language data .': ['Challenges'],
#  'language data . Challenges': ['in'],
#  'data . Challenges in': ['natural'],
#  '. Challenges in natural': ['language'],
#  'Challenges in natural language': ['processing'],
#  'in natural language processing': ['frequently', 'with', ',', '.'],
#  'natural language processing frequently': ['involve'],
#  'language processing frequently involve': ['speech'],
#  'processing frequently involve speech': ['recognition'],
#  'frequently involve speech recognition': [','],
#  'involve speech recognition ,': ['natural'],
#  'speech recognition , natural': ['language'],
#  'recognition , natural language': ['understanding'],
#  ', natural language understanding': [','],
#  'natural language understanding ,': ['and'],
#  'language understanding , and': ['natural'],
#  'understanding , and natural': ['language'],
#  ', and natural language': ['generation'],
#  'and natural language generation': ['.'],
#  'natural language generation .': ['The'],
#  'language generation . The': ['history'],
#  'generation . The history': ['of'],
#  '. The history of': ['natural'],
#  'The history of natural': ['language'],
#  'history of natural language': ['processing'],
#  'of natural language processing': ['('],
#  'natural language processing (': ['NLP'],
#  '( NLP ) generally': ['started'],
#  'NLP ) generally started': ['in'],
#  ') generally started in': ['the'],
#  'generally started in the': ['1950s'],
#  'started in the 1950s': [','],
#  'in the 1950s ,': ['although'],
#  'the 1950s , although': ['work'],
#  '1950s , although work': ['can'],
#  ', although work can': ['be'],
#  'although work can be': ['found'],
#  'work can be found': ['from'],
#  'can be found from': ['earlier'],
#  'be found from earlier': ['periods'],
#  'found from earlier periods': ['.'],
#  'from earlier periods .': ['In'],
#  'earlier periods . In': ['1950'],
#  'periods . In 1950': [','],
#  '. In 1950 ,': ['Alan'],
#  'In 1950 , Alan': ['Turing'],
#  '1950 , Alan Turing': ['published'],
#  ', Alan Turing published': ['an'],
#  'Alan Turing published an': ['article'],
#  'Turing published an article': ['titled'],
#  'published an article titled': ['``'],
#  'an article titled ``': ['Computing'],
#  'article titled `` Computing': ['Machinery'],
#  'titled `` Computing Machinery': ['and'],
#  '`` Computing Machinery and': ['Intelligence'],
#  'Computing Machinery and Intelligence': ["''"],
#  "Machinery and Intelligence ''": ['which'],
#  "and Intelligence '' which": ['proposed'],
#  "Intelligence '' which proposed": ['what'],
#  "'' which proposed what": ['is'],
#  'which proposed what is': ['now'],
#  'proposed what is now': ['called'],
#  'what is now called': ['the'],
#  'is now called the': ['Turing'],
#  'now called the Turing': ['test'],
#  'called the Turing test': ['as'],
#  'the Turing test as': ['a'],
#  'Turing test as a': ['criterion'],
#  'test as a criterion': ['of'],
#  'as a criterion of': ['intelligence'],
#  'a criterion of intelligence': ['.'],
#  'criterion of intelligence .': ['The'],
#  'of intelligence . The': ['Georgetown'],
#  'intelligence . The Georgetown': ['experiment'],
#  '. The Georgetown experiment': ['in'],
#  'The Georgetown experiment in': ['1954'],
#  'Georgetown experiment in 1954': ['involved'],
#  'experiment in 1954 involved': ['fully'],
#  'in 1954 involved fully': ['automatic'],
#  '1954 involved fully automatic': ['translation'],
#  'involved fully automatic translation': ['of'],
#  'fully automatic translation of': ['more'],
#  'automatic translation of more': ['than'],
#  'translation of more than': ['sixty'],
#  'of more than sixty': ['Russian'],
#  'more than sixty Russian': ['sentences'],
#  'than sixty Russian sentences': ['into'],
#  'sixty Russian sentences into': ['English'],
#  'Russian sentences into English': ['.'],
#  'sentences into English .': ['The'],
#  'into English . The': ['authors'],
#  'English . The authors': ['claimed'],
#  '. The authors claimed': ['that'],
#  'The authors claimed that': ['within'],
#  'authors claimed that within': ['three'],
#  'claimed that within three': ['or'],
#  'that within three or': ['five'],
#  'within three or five': ['years'],
#  'three or five years': [','],
#  'or five years ,': ['machine'],
#  'five years , machine': ['translation'],
#  'years , machine translation': ['would'],
#  ', machine translation would': ['be'],
#  'machine translation would be': ['a'],
#  'translation would be a': ['solved'],
#  'would be a solved': ['problem'],
#  'be a solved problem': ['.'],
#  'a solved problem .': ['['],
#  'solved problem . [': ['2'],
#  'problem . [ 2': [']'],
#  '. [ 2 ]': ['However'],
#  '[ 2 ] However': [','],
#  '2 ] However ,': ['real'],
#  '] However , real': ['progress'],
#  'However , real progress': ['was'],
#  ', real progress was': ['much'],
#  'real progress was much': ['slower'],
#  'progress was much slower': [','],
#  'was much slower ,': ['and'],
#  'much slower , and': ['after'],
#  'slower , and after': ['the'],
#  ', and after the': ['ALPAC'],
#  'and after the ALPAC': ['report'],
#  'after the ALPAC report': ['in'],
#  'the ALPAC report in': ['1966'],
#  'ALPAC report in 1966': [','],
#  'report in 1966 ,': ['which'],
#  'in 1966 , which': ['found'],
#  '1966 , which found': ['that'],
#  ', which found that': ['ten-year-long'],
#  'which found that ten-year-long': ['research'],
#  'found that ten-year-long research': ['had'],
#  'that ten-year-long research had': ['failed'],
#  'ten-year-long research had failed': ['to'],
#  'research had failed to': ['fulfill'],
#  'had failed to fulfill': ['the'],
#  'failed to fulfill the': ['expectations'],
#  'to fulfill the expectations': [','],
#  'fulfill the expectations ,': ['funding'],
#  'the expectations , funding': ['for'],
#  'expectations , funding for': ['machine'],
#  ', funding for machine': ['translation'],
#  'funding for machine translation': ['was'],
#  'for machine translation was': ['dramatically'],
#  'machine translation was dramatically': ['reduced'],
#  'translation was dramatically reduced': ['.'],
#  'was dramatically reduced .': ['Little'],
#  'dramatically reduced . Little': ['further'],
#  'reduced . Little further': ['research'],
#  '. Little further research': ['in'],
#  'Little further research in': ['machine'],
#  'further research in machine': ['translation'],
#  'research in machine translation': ['was'],
#  'in machine translation was': ['conducted'],
#  'machine translation was conducted': ['until'],
#  'translation was conducted until': ['the'],
#  'was conducted until the': ['late'],
#  'conducted until the late': ['1980s'],
#  'until the late 1980s': [','],
#  'the late 1980s ,': ['when', 'however'],
#  'late 1980s , when': ['the'],
#  '1980s , when the': ['first'],
#  ', when the first': ['statistical'],
#  'when the first statistical': ['machine'],
#  'the first statistical machine': ['translation'],
#  'first statistical machine translation': ['systems'],
#  'statistical machine translation systems': ['were'],
#  'machine translation systems were': ['developed'],
#  'translation systems were developed': ['.'],
#  'systems were developed .': ['Some'],
#  'were developed . Some': ['notably'],
#  'developed . Some notably': ['successful'],
#  '. Some notably successful': ['natural'],
#  'Some notably successful natural': ['language'],
#  'notably successful natural language': ['processing'],
#  'successful natural language processing': ['systems'],
#  'natural language processing systems': ['developed', 'were'],
#  'language processing systems developed': ['in'],
#  'processing systems developed in': ['the'],
#  'systems developed in the': ['1960s'],
#  'developed in the 1960s': ['were'],
#  'in the 1960s were': ['SHRDLU'],
#  'the 1960s were SHRDLU': [','],
#  '1960s were SHRDLU ,': ['a'],
#  'were SHRDLU , a': ['natural'],
#  'SHRDLU , a natural': ['language'],
#  ', a natural language': ['system'],
#  'a natural language system': ['working'],
#  'natural language system working': ['in'],
#  'language system working in': ['restricted'],
#  'system working in restricted': ['``'],
#  'working in restricted ``': ['blocks'],
#  'in restricted `` blocks': ['worlds'],
#  'restricted `` blocks worlds': ["''"],
#  "`` blocks worlds ''": ['with'],
#  "blocks worlds '' with": ['restricted'],
#  "worlds '' with restricted": ['vocabularies'],
#  "'' with restricted vocabularies": [','],
#  'with restricted vocabularies ,': ['and'],
#  'restricted vocabularies , and': ['ELIZA'],
#  'vocabularies , and ELIZA': [','],
#  ', and ELIZA ,': ['a'],
#  'and ELIZA , a': ['simulation'],
#  'ELIZA , a simulation': ['of'],
#  ', a simulation of': ['a'],
#  'a simulation of a': ['Rogerian'],
#  'simulation of a Rogerian': ['psychotherapist'],
#  'of a Rogerian psychotherapist': [','],
#  'a Rogerian psychotherapist ,': ['written'],
#  'Rogerian psychotherapist , written': ['by'],
#  'psychotherapist , written by': ['Joseph'],
#  ', written by Joseph': ['Weizenbaum'],
#  'written by Joseph Weizenbaum': ['between'],
#  'by Joseph Weizenbaum between': ['1964'],
#  'Joseph Weizenbaum between 1964': ['and'],
#  'Weizenbaum between 1964 and': ['1966'],
#  'between 1964 and 1966': ['.'],
#  '1964 and 1966 .': ['Using'],
#  'and 1966 . Using': ['almost'],
#  '1966 . Using almost': ['no'],
#  '. Using almost no': ['information'],
#  'Using almost no information': ['about'],
#  'almost no information about': ['human'],
#  'no information about human': ['thought'],
#  'information about human thought': ['or'],
#  'about human thought or': ['emotion'],
#  'human thought or emotion': [','],
#  'thought or emotion ,': ['ELIZA'],
#  'or emotion , ELIZA': ['sometimes'],
#  'emotion , ELIZA sometimes': ['provided'],
#  ', ELIZA sometimes provided': ['a'],
#  'ELIZA sometimes provided a': ['startlingly'],
#  'sometimes provided a startlingly': ['human-like'],
#  'provided a startlingly human-like': ['interaction'],
#  'a startlingly human-like interaction': ['.'],
#  'startlingly human-like interaction .': ['When'],
#  'human-like interaction . When': ['the'],
#  'interaction . When the': ['``'],
#  '. When the ``': ['patient'],
#  'When the `` patient': ["''"],
#  "the `` patient ''": ['exceeded'],
#  "`` patient '' exceeded": ['the'],
#  "patient '' exceeded the": ['very'],
#  "'' exceeded the very": ['small'],
#  'exceeded the very small': ['knowledge'],
#  'the very small knowledge': ['base'],
#  'very small knowledge base': [','],
#  'small knowledge base ,': ['ELIZA'],
#  'knowledge base , ELIZA': ['might'],
#  'base , ELIZA might': ['provide'],
#  ', ELIZA might provide': ['a'],
#  'ELIZA might provide a': ['generic'],
#  'might provide a generic': ['response'],
#  'provide a generic response': [','],
#  'a generic response ,': ['for'],
#  'generic response , for': ['example'],
#  'response , for example': [','],
#  ', for example ,': ['responding'],
#  'for example , responding': ['to'],
#  'example , responding to': ['``'],
#  ', responding to ``': ['My'],
#  'responding to `` My': ['head'],
# ...
#  'input data . The': ['cache'],
#  'data . The cache': ['language'],
#  '. The cache language': ['models'],
#  'The cache language models': ['upon'],
#  'cache language models upon': ['which'],
#  'language models upon which': ['many'],
#  'models upon which many': ['speech'],
#  'upon which many speech': ['recognition'],
#  'which many speech recognition': ['systems'],
#  'many speech recognition systems': ['now'],
#  'speech recognition systems now': ['rely'],
#  'recognition systems now rely': ['are'],
#  'systems now rely are': ['examples'],
#  'now rely are examples': ['of'],
#  'rely are examples of': ['such'],
#  'are examples of such': ['statistical'],
#  'examples of such statistical': ['models'],
#  'of such statistical models': ['.'],
#  'such statistical models .': ['Such'],
#  'statistical models . Such': ['models'],
#  'models . Such models': ['are'],
#  '. Such models are': ['generally'],
#  'Such models are generally': ['more'],
#  'models are generally more': ['robust'],
#  'are generally more robust': ['when'],
#  'generally more robust when': ['given'],
#  'more robust when given': ['unfamiliar'],
#  'robust when given unfamiliar': ['input'],
#  'when given unfamiliar input': [','],
#  'given unfamiliar input ,': ['especially'],
#  'unfamiliar input , especially': ['input'],
#  'input , especially input': ['that'],
#  ', especially input that': ['contains'],
#  'especially input that contains': ['errors'],
#  'input that contains errors': ['('],
#  'that contains errors (': ['as'],
#  'contains errors ( as': ['is'],
#  'errors ( as is': ['very'],
#  '( as is very': ['common'],
#  'as is very common': ['for'],
#  'is very common for': ['real-world'],
#  'very common for real-world': ['data'],
#  'common for real-world data': [')'],
#  'for real-world data )': [','],
#  'real-world data ) ,': ['and'],
#  'data ) , and': ['produce'],
#  ') , and produce': ['more'],
#  ', and produce more': ['reliable'],
#  'and produce more reliable': ['results'],
#  'produce more reliable results': ['when'],
#  'more reliable results when': ['integrated', 'such'],
#  'reliable results when integrated': ['into'],
#  'results when integrated into': ['a'],
#  'when integrated into a': ['larger'],
#  'integrated into a larger': ['system'],
#  'into a larger system': ['comprising'],
#  'a larger system comprising': ['multiple'],
#  'larger system comprising multiple': ['subtasks'],
#  'system comprising multiple subtasks': ['.'],
#  'comprising multiple subtasks .': ['Many'],
#  'multiple subtasks . Many': ['of'],
#  'subtasks . Many of': ['the'],
#  '. Many of the': ['notable'],
#  'Many of the notable': ['early'],
#  'of the notable early': ['successes'],
#  'the notable early successes': ['occurred'],
#  'notable early successes occurred': ['in'],
#  'early successes occurred in': ['the'],
#  'successes occurred in the': ['field'],
#  'occurred in the field': ['of'],
#  'in the field of': ['machine'],
#  'the field of machine': ['translation'],
#  'field of machine translation': [','],
#  'of machine translation ,': ['due'],
#  'machine translation , due': ['especially'],
#  'translation , due especially': ['to'],
#  ', due especially to': ['work'],
#  'due especially to work': ['at'],
#  'especially to work at': ['IBM'],
#  'to work at IBM': ['Research'],
#  'work at IBM Research': [','],
#  'at IBM Research ,': ['where'],
#  'IBM Research , where': ['successively'],
#  'Research , where successively': ['more'],
#  ', where successively more': ['complicated'],
#  'where successively more complicated': ['statistical'],
#  'successively more complicated statistical': ['models'],
#  'more complicated statistical models': ['were'],
#  'complicated statistical models were': ['developed'],
#  'statistical models were developed': ['.'],
#  'models were developed .': ['These'],
#  'were developed . These': ['systems'],
#  'developed . These systems': ['were'],
#  '. These systems were': ['able'],
#  'These systems were able': ['to'],
#  'systems were able to': ['take'],
#  'were able to take': ['advantage'],
#  'able to take advantage': ['of'],
#  'to take advantage of': ['existing'],
#  'take advantage of existing': ['multilingual'],
#  'advantage of existing multilingual': ['textual'],
#  'of existing multilingual textual': ['corpora'],
#  'existing multilingual textual corpora': ['that'],
#  'multilingual textual corpora that': ['had'],
#  'textual corpora that had': ['been'],
#  'corpora that had been': ['produced'],
#  'that had been produced': ['by'],
#  'had been produced by': ['the'],
#  'been produced by the': ['Parliament'],
#  'produced by the Parliament': ['of'],
#  'by the Parliament of': ['Canada'],
#  'the Parliament of Canada': ['and'],
#  'Parliament of Canada and': ['the'],
#  'of Canada and the': ['European'],
#  'Canada and the European': ['Union'],
#  'and the European Union': ['as'],
#  'the European Union as': ['a'],
#  'European Union as a': ['result'],
#  'Union as a result': ['of'],
#  'as a result of': ['laws'],
#  'a result of laws': ['calling'],
#  'result of laws calling': ['for'],
#  'of laws calling for': ['the'],
#  'laws calling for the': ['translation'],
#  'calling for the translation': ['of'],
#  'for the translation of': ['all'],
#  'the translation of all': ['governmental'],
#  'translation of all governmental': ['proceedings'],
#  'of all governmental proceedings': ['into'],
#  'all governmental proceedings into': ['all'],
#  'governmental proceedings into all': ['official'],
#  'proceedings into all official': ['languages'],
#  'into all official languages': ['of'],
#  'all official languages of': ['the'],
#  'official languages of the': ['corresponding'],
#  'languages of the corresponding': ['systems'],
#  'of the corresponding systems': ['of'],
#  'the corresponding systems of': ['government'],
#  'corresponding systems of government': ['.'],
#  'systems of government .': ['However'],
#  'of government . However': [','],
#  'government . However ,': ['most'],
#  '. However , most': ['other'],
#  'However , most other': ['systems'],
#  ', most other systems': ['depended'],
#  'most other systems depended': ['on'],
#  'other systems depended on': ['corpora'],
#  'systems depended on corpora': ['specifically'],
#  'depended on corpora specifically': ['developed'],
#  'on corpora specifically developed': ['for'],
#  'corpora specifically developed for': ['the'],
#  'specifically developed for the': ['tasks'],
#  'developed for the tasks': ['implemented'],
#  'for the tasks implemented': ['by'],
#  'the tasks implemented by': ['these'],
#  'tasks implemented by these': ['systems'],
#  'implemented by these systems': [','],
#  'by these systems ,': ['which'],
#  'these systems , which': ['was'],
#  'systems , which was': ['('],
#  ', which was (': ['and'],
#  'which was ( and': ['often'],
#  'was ( and often': ['continues'],
#  '( and often continues': ['to'],
#  'and often continues to': ['be'],
#  'often continues to be': [')'],
#  'continues to be )': ['a'],
#  'to be ) a': ['major'],
#  'be ) a major': ['limitation'],
#  ') a major limitation': ['in'],
#  'a major limitation in': ['the'],
#  'major limitation in the': ['success'],
#  'limitation in the success': ['of'],
#  'in the success of': ['these'],
#  'the success of these': ['systems'],
#  'success of these systems': ['.'],
#  'of these systems .': ['As'],
#  'these systems . As': ['a'],
#  'systems . As a': ['result'],
#  '. As a result': [','],
#  'As a result ,': ['a'],
#  'a result , a': ['great'],
#  'result , a great': ['deal'],
#  ', a great deal': ['of'],
#  'a great deal of': ['research'],
#  'great deal of research': ['has'],
#  'deal of research has': ['gone'],
#  'of research has gone': ['into'],
#  'research has gone into': ['methods'],
#  'has gone into methods': ['of'],
#  'gone into methods of': ['more'],
#  'into methods of more': ['effectively'],
#  'methods of more effectively': ['learning'],
#  'of more effectively learning': ['from'],
#  'more effectively learning from': ['limited'],
#  'effectively learning from limited': ['amounts'],
#  'learning from limited amounts': ['of'],
#  'from limited amounts of': ['data'],
#  'limited amounts of data': ['.'],
#  'amounts of data .': ['Recent'],
#  'of data . Recent': ['research'],
#  'data . Recent research': ['has'],
#  '. Recent research has': ['increasingly'],
#  'Recent research has increasingly': ['focused'],
#  'research has increasingly focused': ['on'],
#  'has increasingly focused on': ['unsupervised'],
#  'increasingly focused on unsupervised': ['and'],
#  'focused on unsupervised and': ['semi-supervised'],
#  'on unsupervised and semi-supervised': ['learning'],
#  'unsupervised and semi-supervised learning': ['algorithms'],
#  'and semi-supervised learning algorithms': ['.'],
#  'semi-supervised learning algorithms .': ['Such'],
#  'learning algorithms . Such': ['algorithms'],
#  'algorithms . Such algorithms': ['are'],
#  '. Such algorithms are': ['able'],
#  'Such algorithms are able': ['to'],
#  'algorithms are able to': ['learn'],
#  'are able to learn': ['from'],
#  'able to learn from': ['data'],
#  'to learn from data': ['that'],
#  'learn from data that': ['has'],
#  'from data that has': ['not'],
#  'data that has not': ['been'],
#  'that has not been': ['hand-annotated'],
#  'has not been hand-annotated': ['with'],
#  'not been hand-annotated with': ['the'],
#  'been hand-annotated with the': ['desired'],
#  'hand-annotated with the desired': ['answers'],
#  'with the desired answers': [','],
#  'the desired answers ,': ['or'],
#  'desired answers , or': ['using'],
#  'answers , or using': ['a'],
#  ', or using a': ['combination'],
#  'or using a combination': ['of'],
#  'using a combination of': ['annotated'],
#  'a combination of annotated': ['and'],
#  'combination of annotated and': ['non-annotated'],
#  'of annotated and non-annotated': ['data'],
#  'annotated and non-annotated data': ['.'],
#  'and non-annotated data .': ['Generally'],
#  'non-annotated data . Generally': [','],
#  'data . Generally ,': ['this'],
#  '. Generally , this': ['task'],
#  'Generally , this task': ['is'],
#  ', this task is': ['much'],
#  'this task is much': ['more'],
#  'task is much more': ['difficult'],
#  'is much more difficult': ['than'],
#  'much more difficult than': ['supervised'],
#  'more difficult than supervised': ['learning'],
#  'difficult than supervised learning': [','],
#  'than supervised learning ,': ['and'],
#  'supervised learning , and': ['typically'],
#  'learning , and typically': ['produces'],
#  ', and typically produces': ['less'],
#  'and typically produces less': ['accurate'],
#  'typically produces less accurate': ['results'],
#  'produces less accurate results': ['for'],
#  'less accurate results for': ['a'],
#  'accurate results for a': ['given'],
#  'results for a given': ['amount'],
#  'for a given amount': ['of'],
#  'a given amount of': ['input'],
#  'given amount of input': ['data'],
#  'amount of input data': ['.'],
#  'of input data .': ['However'],
#  'input data . However': [','],
#  'data . However ,': ['there'],
#  '. However , there': ['is'],
#  'However , there is': ['an'],
#  ', there is an': ['enormous'],
#  'there is an enormous': ['amount'],
#  'is an enormous amount': ['of'],
#  'an enormous amount of': ['non-annotated'],
#  'enormous amount of non-annotated': ['data'],
#  'amount of non-annotated data': ['available'],
#  'of non-annotated data available': ['('],
#  'non-annotated data available (': ['including'],
#  'data available ( including': [','],
#  'available ( including ,': ['among'],
#  '( including , among': ['other'],
#  'including , among other': ['things'],
#  ', among other things': [','],
#  'among other things ,': ['the'],
#  'other things , the': ['entire'],
#  'things , the entire': ['content'],
#  ', the entire content': ['of'],
#  'the entire content of': ['the'],
#  'entire content of the': ['World'],
#  'content of the World': ['Wide'],
#  'of the World Wide': ['Web'],
#  'the World Wide Web': [')'],
#  'World Wide Web )': [','],
#  'Wide Web ) ,': ['which'],
#  'Web ) , which': ['can'],
#  ') , which can': ['often'],
#  ', which can often': ['make'],
#  'which can often make': ['up'],
#  'can often make up': ['for'],
#  'often make up for': ['the'],
#  'make up for the': ['inferior'],
#  'up for the inferior': ['results'],
#  'for the inferior results': ['if'],
#  'the inferior results if': ['the'],
#  'inferior results if the': ['algorithm'],
#  'results if the algorithm': ['used'],
#  'if the algorithm used': ['has'],
#  'the algorithm used has': ['a'],
#  'algorithm used has a': ['low'],
#  'used has a low': ['enough'],
#  'has a low enough': ['time'],
#  'a low enough time': ['complexity'],
#  'low enough time complexity': ['to'],
#  'enough time complexity to': ['be'],
#  'time complexity to be': ['practical'],
#  'complexity to be practical': ['.'],
#  'to be practical .': ['In'],
#  'be practical . In': ['the'],
#  'practical . In the': ['2010s'],
#  '. In the 2010s': [','],
#  'In the 2010s ,': ['representation'],
#  'the 2010s , representation': ['learning'],
#  '2010s , representation learning': ['and'],
#  ', representation learning and': ['deep'],
#  'representation learning and deep': ['neural'],
#  'learning and deep neural': ['network-style'],
#  'and deep neural network-style': ['machine'],
#  'deep neural network-style machine': ['learning'],
#  'neural network-style machine learning': ['methods'],
#  'network-style machine learning methods': ['became'],
#  'machine learning methods became': ['widespread'],
#  'learning methods became widespread': ['in'],
#  'methods became widespread in': ['natural'],
#  'became widespread in natural': ['language'],
#  'widespread in natural language': ['processing'],
#  'language processing , due': ['in'],
#  'processing , due in': ['part'],
#  ', due in part': ['to'],
#  'due in part to': ['a'],
#  'in part to a': ['flurry'],
#  'part to a flurry': ['of'],
#  'to a flurry of': ['results'],
#  'a flurry of results': ['showing'],
#  'flurry of results showing': ['that'],
#  'of results showing that': ['such'],
#  'results showing that such': ['techniques'],
#  'showing that such techniques': ['['],
#  'that such techniques [': ['4'],
#  'such techniques [ 4': [']'],
#  'techniques [ 4 ]': ['['],
#  '[ 4 ] [': ['5'],
#  '4 ] [ 5': [']'],
#  '] [ 5 ]': ['can'],
#  '[ 5 ] can': ['achieve'],
#  '5 ] can achieve': ['state-of-the-art'],
#  '] can achieve state-of-the-art': ['results'],
#  'can achieve state-of-the-art results': ['in'],
#  'achieve state-of-the-art results in': ['many'],
#  'state-of-the-art results in many': ['natural'],
#  'results in many natural': ['language'],
#  'in many natural language': ['tasks'],
#  'many natural language tasks': [','],
#  'natural language tasks ,': ['for'],
#  'language tasks , for': ['example'],
#  'tasks , for example': ['in'],
#  ', for example in': ['language'],
#  'for example in language': ['modeling'],
#  'example in language modeling': [','],
#  'in language modeling ,': ['['],
#  'language modeling , [': ['6'],
#  'modeling , [ 6': [']'],
#  ', [ 6 ]': ['parsing'],
#  '[ 6 ] parsing': [','],
#  '6 ] parsing ,': ['['],
#  '] parsing , [': ['7'],
#  'parsing , [ 7': [']'],
#  ', [ 7 ]': ['['],
#  '[ 7 ] [': ['8'],
#  '7 ] [ 8': [']'],
#  '] [ 8 ]': ['and'],
#  '[ 8 ] and': ['many'],
#  '8 ] and many': ['others'],
#  '] and many others': ['.'],
#  'and many others .': ['Popular'],
#  'many others . Popular': ['techniques'],
#  'others . Popular techniques': ['include'],
#  '. Popular techniques include': ['the'],
#  'Popular techniques include the': ['use'],
#  'techniques include the use': ['of'],
#  'include the use of': ['word'],
#  'the use of word': ['embeddings'],
#  'use of word embeddings': ['to'],
#  'of word embeddings to': ['capture'],
#  'word embeddings to capture': ['semantic'],
#  'embeddings to capture semantic': ['properties'],
#  'to capture semantic properties': ['of'],
#  'capture semantic properties of': ['words'],
#  'semantic properties of words': [','],
#  'properties of words ,': ['and'],
#  'of words , and': ['an'],
#  'words , and an': ['increase'],
#  ', and an increase': ['in'],
#  'and an increase in': ['end-to-end'],
#  'an increase in end-to-end': ['learning'],
#  'increase in end-to-end learning': ['of'],
#  'in end-to-end learning of': ['a'],
#  'end-to-end learning of a': ['higher-level'],
#  'learning of a higher-level': ['task'],
#  'of a higher-level task': ['('],
#  'a higher-level task (': ['e.g.'],
#  'higher-level task ( e.g.': [','],
#  'task ( e.g. ,': ['question'],
#  '( e.g. , question': ['answering'],
#  'e.g. , question answering': [')'],
#  ', question answering )': ['instead'],
#  'question answering ) instead': ['of'],
#  ...}

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) is a subfield of linguistics , computer science , information engineering , and artificial intelligence concerned with the interactions between computers and human ( natural ) languages , in particular how to program computers to process and analyze large amounts of natural language data . Challenges in natural
